# %% [markdown]
# <center>
# <img src="FIFA-19-Background-1-768x401.jpg" />
#
# ## Aprendizaje No Supervisado 2020 DiploDatos
#     Laura Alonso Alemany, Ana Georgina Flesia y Valeria Rulloni
# ## Agrupamiento con el FIFA 2019 dataset
#
# Material basado en notas de Ana Georgina Flesia bajo los términos y condiciones de la licencia [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/), a su vez basado de material de [SilveMel](https://www.kaggle.com/karangadiya/fifa19/downloads/data.csv/comments) y otros.

# %% [markdown]
# ### Indice de temas
# 1. [Inicialización del entorno](#1.-Inicialización-del-entorno)
# 2. [Exploración de la Base](#2.-Exploración-de-la-base)
# 3. [Preparación de los datos](#3.-Preparación-de-los-datos)
# 4. [Clustering Visual](#3.-Exploratorio-Visual-para-Clustering)

# %% [markdown]
# ## 1.-Inicialización-del-entorno

# %% [markdown]
# **Empezamos cargando algunas herramientas para cargar los datos y manipularlos.**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)
import itertools
import warnings
warnings.filterwarnings("ignore")
import io

# %% [markdown]
# **Para visualización usaremos principalmente plotly, también seaborn y matplotlib.**

# %%
from plotly.offline import init_notebook_mode, plot,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2.-Exploración-de-la-base

# %% [markdown]
# **Cargamos los datos bajados de la database de [Kaggle](https://www.kaggle.com/karangadiya/fifa19) (https://www.kaggle.com/karangadiya/fifa19) como 'data.csv'.**

# %%
df=pd.read_csv("players_20.csv")
df.head(4)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 3        188         87    Slovenia      Atlético Madrid       91         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 3   77500000    125000               GK          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# 1                         5          4            5       High/Low
# 2                         5          5            5    High/Medium
# 3                         3          3            1  Medium/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
#
#    attacking_volleys  skill_dribbling  ...  movement_acceleration  \
# 0                 88               97  ...                     91
# 1                 87               89  ...                     89
# 2                 87               96  ...                     94
# 3                 13               12  ...                     43
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                    89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
#
# [4 rows x 104 columns]

# %%
df.tail(4)
# Me devuelve las últimas 'n' filas, en este caso 4, si 'n' es negativo me devuelve todas las filas excepto las n primeras
# Out:
#        sofifa_id                                         player_url  \
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  overall  potential  \
# 18274    China PR               Shanghai SIPG FC       48         56
# 18275    China PR         Hebei China Fortune FC       48         56
# 18276    China PR  Shanghai Greenland Shenhua FC       48         54
# 18277    China PR         Hebei China Fortune FC       48         51
#
#        value_eur  wage_eur player_positions preferred_foot  \
# 18274      40000      2000               CB          Right
# 18275      40000      1000               CM          Right
# 18276      40000      1000               CM          Right
# 18277      40000      2000               CM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 18274                         1          2            2  Medium/Medium
# 18275                         1          2            2     Low/Medium
# 18276                         1          2            2        Low/Low
# 18277                         1          3            2  Medium/Medium
#
#       body_type real_face  release_clause_eur player_tags team_position  \
# 18274    Normal        No             72000.0         NaN           SUB
# 18275      Lean        No             70000.0         NaN           SUB
# 18276      Lean        No             70000.0         NaN           SUB
# 18277    Normal        No                 NaN         NaN           SUB
#
#        team_jersey_number      loaned_from      joined  contract_valid_until  \
# 18274                31.0              NaN  2019-02-01                2022.0
# 18275                38.0              NaN  2019-01-01                2019.0
# 18276                33.0              NaN  2019-02-01                2022.0
# 18277                37.0  Tianjin TEDA FC         NaN                2019.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 18274             NaN                   NaN  58.0      24.0     33.0
# 18275             NaN                   NaN  54.0      35.0     44.0
# 18276             NaN                   NaN  59.0      35.0     47.0
# 18277             NaN                   NaN  60.0      32.0     51.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 18274       35.0       48.0    48.0        NaN          NaN         NaN
# 18275       45.0       48.0    51.0        NaN          NaN         NaN
# 18276       47.0       45.0    52.0        NaN          NaN         NaN
# 18277       45.0       47.0    55.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning player_traits  \
# 18274          NaN       NaN             NaN           NaN
# 18275          NaN       NaN             NaN           NaN
# 18276          NaN       NaN             NaN           NaN
# 18277          NaN       NaN             NaN           NaN
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 18274                  24                   20                          42
# 18275                  32                   33                          49
# 18276                  39                   34                          47
# 18277                  44                   30                          48
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  ...  \
# 18274                       43                 28               32  ...
# 18275                       53                 32               40  ...
# 18276                       54                 28               42  ...
# 18277                       58                 25               40  ...
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 18274                     55                     61                43
# 18275                     55                     54                52
# 18276                     55                     63                55
# 18277                     54                     64                52
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 18274                  41                76                33             72
# 18275                  52                57                48             60
# 18276                  54                59                46             61
# 18277                  49                71                41             64
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 18274             55              44                20                    42
# 18275             50              51                26                    50
# 18276             42              55                28                    57
# 18277             40              61                30                    54
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 18274                       49                     23                25
# 18275                       45                     38                38
# 18276                       49                     31                48
# 18277                       47                     29                52
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 18274                   37                   35                 42
# 18275                   36                   39                 46
# 18276                   36                   40                 39
# 18277                   38                   42                 52
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 18274                         53                        57
# 18275                         52                        46
# 18276                         44                        54
# 18277                         42                        48
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 18274                  13                     6                   14
# 18275                   7                     8                   10
# 18276                  14                     9                   13
# 18277                   8                    12                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 18274                       11                     9  33+2  33+2  33+2  33+2
# 18275                        6                    14  43+2  43+2  43+2  43+2
# 18276                       13                    13  43+2  43+2  43+2  45+2
# 18277                        9                    10  42+2  42+2  42+2  44+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 18274  32+2  32+2  32+2  33+2  33+2  33+2  33+2  35+2  36+2  36+2  36+2  35+2
# 18275  43+2  43+2  43+2  43+2  44+2  44+2  44+2  45+2  46+2  46+2  46+2  45+2
# 18276  44+2  44+2  44+2  45+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
# 18277  43+2  43+2  43+2  44+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 18274  44+2  43+2  43+2  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  47+2  49+2  49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  49+2  49+2  49+2  48+2  48+2  50+2  50+2  50+2  48+2
#
# [4 rows x 104 columns]

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print(df.columns[:77])
print(len(df.columns))
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning'],
#       dtype='object')
# 104

# %% [markdown]
# La variable **'Overall'** se calcula usando otras variables de desempeño del jugador (skills_ratings).
#
# La variable 'Overall' es discreta, así como las otras de desempeño según habilidad ('Crossing',
#        'Finishing', 'HeadingAccuracy', etc.), tomando valores enteros entre 0 y 100
#
# Miramos ahora los mejores jugadores por posicion, usando las variables 'Overall' y 'Position'.

# %% [markdown]
# **Realizamos el histograma de la variable "Overall" (Desempeño global)**

# %%
df['overall'].hist(bins = 20)

# %%
best_players_per_position=df.iloc[df.groupby(df['team_position'])['overall'].idxmax()][['team_position','short_name','overall']]
best_players_per_position
# Out:
#     team_position           short_name  overall
# 2             CAM            Neymar Jr       92
# 126            CB           S. de Vrij       84
# 21            CDM      Sergio Busquets       89
# 46             CF           K. Benzema       87
# 123            CM         Luis Alberto       84
# 3              GK             J. Oblak       91
# 306           LAM               Taison       82
# 51             LB           Jordi Alba       87
# 7             LCB          V. van Dijk       90
# 33            LCM          David Silva       88
# 24            LDM             P. Pogba       88
# 259            LF          K. Demirbay       82
# 38             LM        P. Aubameyang       88
# 54             LS           L. Insigne       87
# 1              LW    Cristiano Ronaldo       93
# 483           LWB       M. Halstenberg       80
# 95            RAM            H. Ziyech       85
# 61             RB           J. Kimmich       86
# 29            RCB                Piqué       88
# 5             RCM         K. De Bruyne       91
# 78            RDM  S. Milinković-Savić       85
# 93            RES            M. Icardi       85
# 109            RF           K. Havertz       84
# 27             RM           C. Eriksen       88
# 104            RS           Iago Aspas       85
# 0              RW             L. Messi       94
# 476           RWB         P. Kadeřábek       80
# 12             ST              H. Kane       89
# 48            SUB           D. Mertens       87

# %%
pd.DataFrame(df.team_position.value_counts().sort_index())
# Out:
#      team_position
# CAM            311
# CB             100
# CDM            181
# CF              14
# CM              76
# GK             662
# LAM             23
# LB             560
# LCB            660
# LCM            411
# LDM            242
# LF              19
# LM             398
# LS             195
# LW             162
# LWB             58
# RAM             23
# RB             560
# RCB            660
# RCM            411
# RDM            244
# RES           2958
# RF              19
# RM             399
# RS             195
# RW             161
# RWB             58
# ST             458
# SUB           7820

# %%
club_avg_overall=df.groupby("club")["overall"].mean().reset_index().sort_values("overall",ascending=False)
club_avg_overall.head(8)
# Out:
#                   club    overall
# 226  FC Bayern München  81.304348
# 505        Real Madrid  80.121212
# 350           Juventus  80.060606
# 650            Uruguay  78.608696
# 224       FC Barcelona  78.363636
# 407             Mexico  78.000000
# 426        Netherlands  78.000000
# 166           Colombia  78.000000

# %% [markdown]
# ## 2.-Preparación-de-los-datos

# %% [markdown]
# **Retiramos jugadores con bajo Desempeño global ("Overall"), reducimos el tamaño de la base**
#
# **y consideramos Variables de desempeño por habilidad (skills_ratings)**

# %%
n=10000 #cantidad de jugadores a considerar

df_n=df.loc[:n] #se reduce la base a los n primeros jugadores

df_n=df_n[(df_n['overall']>70)]

skills_ratings = ['attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_standing_tackle',
       'defending_sliding_tackle', 'goalkeeping_diving',
       'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning']

print(len(skills_ratings), 'variables numéricas de desempeño según habilidad')
# Out:
# 33 variables numéricas de desempeño según habilidad

# %% [markdown]
# **Se crea el jugador perfecto para ver a donde se ubica en nuestra visualización**

# %%
MachineGunDict={'short_name':'MachineGun','overall':99}
for skills in skills_ratings:
    MachineGunDict[skills]=99
    
df_n=df_n.append(MachineGunDict,ignore_index=True)

# %%
df_skills=df_n[skills_ratings] #base, sólo con desempeños según habilidad (numéricas)

# %%
df_skills.head(4)
# Out:
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                  88                   95                          70
# 1                  84                   94                          89
# 2                  87                   87                          62
# 3                  13                   11                          15
#
#    attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 0                       92                 88               97           93
# 1                       83                 87               89           81
# 2                       87                 87               96           88
# 3                       43                 13               12           13
#
#    skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0                 94                  92                  96
# 1                 76                  77                  92
# 2                 87                  81                  95
# 3                 14                  40                  30
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                     91                     84                93
# 1                     89                     91                87
# 2                     94                     89                96
# 3                     43                     60                67
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                  95                95                86             68
# 1                  96                71                95             95
# 2                  92                84                80             61
# 3                  88                49                59             78
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0             75              68                94                    48
# 1             85              78                93                    63
# 2             81              49                84                    51
# 3             41              78                12                    34
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90

# %%
# Verificamos que no hayan valores nulos en nuestras variables de skill
df_skills.isna().sum()
# Out:
# attacking_crossing            0
# attacking_finishing           0
# attacking_heading_accuracy    0
# attacking_short_passing       0
# attacking_volleys             0
# skill_dribbling               0
# skill_curve                   0
# skill_fk_accuracy             0
# skill_long_passing            0
# skill_ball_control            0
# movement_acceleration         0
# movement_sprint_speed         0
# movement_agility              0
# movement_reactions            0
# movement_balance              0
# power_shot_power              0
# power_jumping                 0
# power_stamina                 0
# power_strength                0
# power_long_shots              0
# mentality_aggression          0
# mentality_interceptions       0
# mentality_positioning         0
# mentality_vision              0
# mentality_penalties           0
# mentality_composure           0
# defending_marking             0
# defending_standing_tackle     0
# defending_sliding_tackle      0
# goalkeeping_diving            0
# goalkeeping_handling          0
# goalkeeping_kicking           0
# goalkeeping_positioning       0
# dtype: int64

# %% [markdown]
# ## 3.-Exploratorio-Visual-para-Clustering

# %% [markdown]
# **Visualizamos los datos de a dos variables numéricas**
#
# **Consigna de trabajo en grupo: buscar agrupamiento de datos usando las variables en skill_ratings de a pares**

# %%
df_n.head()
# Out:
#    sofifa_id                                         player_url  \
# 0   158023.0  https://sofifa.com/player/158023/lionel-messi/...
# 1    20801.0  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2   190871.0  https://sofifa.com/player/190871/neymar-da-sil...
# 3   200389.0  https://sofifa.com/player/200389/jan-oblak/20/...
# 4   183277.0  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name   age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior  27.0  1992-02-05
# 3           J. Oblak                            Jan Oblak  26.0  1993-01-07
# 4          E. Hazard                          Eden Hazard  28.0  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0      170.0       72.0   Argentina         FC Barcelona       94       94.0
# 1      187.0       83.0    Portugal             Juventus       93       93.0
# 2      175.0       68.0      Brazil  Paris Saint-Germain       92       92.0
# 3      188.0       87.0    Slovenia      Atlético Madrid       91       93.0
# 4      175.0       74.0     Belgium          Real Madrid       91       91.0
#
#      value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000.0  565000.0       RW, CF, ST           Left
# 1   58500000.0  405000.0           ST, LW          Right
# 2  105500000.0  290000.0          LW, CAM          Right
# 3   77500000.0  125000.0               GK          Right
# 4   90000000.0  470000.0           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                       5.0        4.0          4.0     Medium/Low
# 1                       5.0        4.0          5.0       High/Low
# 2                       5.0        5.0          5.0    High/Medium
# 3                       3.0        3.0          1.0  Medium/Medium
# 4                       4.0        4.0          4.0    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  ...  movement_acceleration  \
# 0                 88               97  ...                     91
# 1                 87               89  ...                     89
# 2                 87               96  ...                     94
# 3                 13               12  ...                     43
# 4                 83               95  ...                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
# 4                         27                        22                  11
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
# 4                    12                    6                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                   8.0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                  11.0  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                  11.0  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                  89.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                   8.0  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
# 4  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
df_n.drop(skills_ratings, axis=1).columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'goalkeeping_reflexes', 'ls', 'st',
#        'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm',
#        'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
#        'rcb', 'rb'],
#       dtype='object')

# %%
df_n.drop(skills_ratings, axis=1).head()
# Out:
#    sofifa_id                                         player_url  \
# 0   158023.0  https://sofifa.com/player/158023/lionel-messi/...
# 1    20801.0  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2   190871.0  https://sofifa.com/player/190871/neymar-da-sil...
# 3   200389.0  https://sofifa.com/player/200389/jan-oblak/20/...
# 4   183277.0  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name   age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior  27.0  1992-02-05
# 3           J. Oblak                            Jan Oblak  26.0  1993-01-07
# 4          E. Hazard                          Eden Hazard  28.0  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0      170.0       72.0   Argentina         FC Barcelona       94       94.0
# 1      187.0       83.0    Portugal             Juventus       93       93.0
# 2      175.0       68.0      Brazil  Paris Saint-Germain       92       92.0
# 3      188.0       87.0    Slovenia      Atlético Madrid       91       93.0
# 4      175.0       74.0     Belgium          Real Madrid       91       91.0
#
#      value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000.0  565000.0       RW, CF, ST           Left
# 1   58500000.0  405000.0           ST, LW          Right
# 2  105500000.0  290000.0          LW, CAM          Right
# 3   77500000.0  125000.0               GK          Right
# 4   90000000.0  470000.0           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                       5.0        4.0          4.0     Medium/Low
# 1                       5.0        4.0          5.0       High/Low
# 2                       5.0        5.0          5.0    High/Medium
# 3                       3.0        3.0          1.0  Medium/Medium
# 4                       4.0        4.0          4.0    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  goalkeeping_reflexes  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                   8.0
# 1  Long Throw-in, Selfish, Argues with Officials,...                  11.0
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  11.0
# 3                         Flair, Acrobatic Clearance                  89.0
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                   8.0
#
#      ls    st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm  \
# 0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2
# 1  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3
# 2  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3
#
#     lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 0  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2
# 1  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3
# 2  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3
#
#     rcb    rb
# 0  52+2  63+2
# 1  53+3  61+3
# 2  46+3  61+3
# 3   NaN   NaN
# 4  49+3  61+3

# %%
df_n[skills_ratings].describe()
# Out:
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# count         4757.000000          4757.000000                 4757.000000
# mean            58.262771            54.057179                   59.449022
# std             19.057687            20.483703                   18.241367
# min              6.000000             5.000000                    7.000000
# 25%             49.000000            40.000000                   52.000000
# 50%             65.000000            60.000000                   64.000000
# 75%             72.000000            70.000000                   72.000000
# max             99.000000            99.000000                   99.000000
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# count              4757.000000        4757.000000      4757.000000
# mean                 67.698760          51.823839        64.320790
# std                  13.742444          19.371476        18.872155
# min                  11.000000           5.000000         7.000000
# 25%                  66.000000          38.000000        60.000000
# 50%                  71.000000          56.000000        71.000000
# 75%                  75.000000          67.000000        76.000000
# max                  99.000000          99.000000        99.000000
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# count  4757.000000        4757.000000         4757.000000         4757.000000
# mean     57.134959          51.144839           61.889847           67.685306
# std      19.546689          19.273338           14.419714           16.130121
# min       6.000000           4.000000            9.000000            5.000000
# 25%      46.000000          37.000000           57.000000           66.000000
# 50%      63.000000          54.000000           65.000000           72.000000
# 75%      72.000000          67.000000           72.000000           76.000000
# max      99.000000          99.000000           99.000000           99.000000
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# count            4757.000000            4757.000000       4757.000000
# mean               67.452596              67.633172         67.712214
# std                14.561249              14.222689         14.253701
# min                15.000000              16.000000         14.000000
# 25%                59.000000              60.000000         60.000000
# 50%                69.000000              70.000000         70.000000
# 75%                78.000000              77.000000         77.000000
# max                99.000000              99.000000         99.000000
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# count         4757.000000       4757.000000       4757.000000    4757.000000
# mean            71.824679         65.586294         67.830986      68.633593
# std              5.584465         14.534318         11.524375      11.849742
# min             54.000000         20.000000         15.000000      29.000000
# 25%             68.000000         57.000000         60.000000      62.000000
# 50%             72.000000         68.000000         70.000000      70.000000
# 75%             75.000000         76.000000         76.000000      77.000000
# max             99.000000         99.000000         99.000000      99.000000
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# count    4757.000000     4757.000000       4757.000000           4757.000000
# mean       69.149674       69.867774         56.995796             64.027328
# std        14.882321       11.546919         19.788059             17.007064
# min        13.000000       26.000000          5.000000             11.000000
# 25%        65.000000       63.000000         47.000000             55.000000
# 50%        72.000000       71.000000         64.000000             69.000000
# 75%        78.000000       78.000000         71.000000             76.000000
# max        99.000000       99.000000         99.000000             99.000000
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# count              4757.000000            4757.000000       4757.000000
# mean                 54.128232              58.877234         62.899727
# std                  22.016307              20.533539         13.361799
# min                   7.000000               3.000000         10.000000
# 25%                  33.000000              50.000000         56.000000
# 50%                  64.000000              67.000000         66.000000
# 75%                  73.000000              73.000000         73.000000
# max                  99.000000              99.000000         99.000000
#
#        mentality_penalties  mentality_composure  defending_marking  \
# count          4757.000000          4757.000000        4757.000000
# mean             55.392684            69.299138          53.779062
# std              16.532943             8.903975          21.563590
# min               9.000000            17.000000           7.000000
# 25%              45.000000            65.000000          35.000000
# 50%              59.000000            70.000000          62.000000
# 75%              68.000000            75.000000          72.000000
# max              99.000000            99.000000          99.000000
#
#        defending_standing_tackle  defending_sliding_tackle  \
# count                4757.000000               4757.000000
# mean                   53.898676                 51.014085
# std                    23.421518                 23.560830
# min                     7.000000                  8.000000
# 25%                    32.000000                 27.000000
# 50%                    65.000000                 61.000000
# 75%                    74.000000                 72.000000
# max                    99.000000                 99.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count         4757.000000           4757.000000          4757.000000
# mean            16.657347             16.443347            16.251839
# std             19.244976             18.344544            17.700173
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             99.000000             99.000000            99.000000
#
#        goalkeeping_positioning
# count              4757.000000
# mean                 16.569687
# std                  18.832135
# min                   1.000000
# 25%                   8.000000
# 50%                  11.000000
# 75%                  14.000000
# max                  99.000000

# %%
# Agrupamos de acuerdo a la posición de los jugadores, y nos fijamos donde se ubican el %75 de los datos 
# de nuestras variables, que sería la mayoría de los datos.
df_n_playerp=df_n.groupby(by=['team_position'])[skills_ratings].quantile(.75)
df_n_playerp
# Out:
#                attacking_crossing  attacking_finishing  \
# team_position
# CAM                         75.00                73.00
# CB                          53.75                43.00
# CDM                         71.00                63.75
# CF                          74.00                83.00
# CM                          73.50                64.75
# GK                          18.00                15.00
# LAM                         75.00                73.00
# LB                          78.00                58.00
# LCB                         59.00                43.00
# LCM                         73.00                69.00
# LDM                         69.00                65.00
# LF                          71.00                72.50
# LM                          74.00                73.00
# LS                          69.00                78.00
# LW                          75.00                76.00
# LWB                         76.75                62.75
# RAM                         76.00                72.00
# RB                          77.00                58.00
# RCB                         57.00                42.00
# RCM                         72.00                68.00
# RDM                         68.00                63.00
# RES                         72.00                69.75
# RF                          74.00                75.50
# RM                          76.25                73.00
# RS                          68.25                78.00
# RW                          76.00                76.00
# RWB                         77.00                59.00
# ST                          66.00                79.00
# SUB                         72.00                71.00
#
#                attacking_heading_accuracy  attacking_short_passing  \
# team_position
# CAM                                 63.00                    79.00
# CB                                  78.00                    73.25
# CDM                                 68.00                    79.00
# CF                                  78.00                    79.00
# CM                                  62.00                    80.00
# GK                                  17.00                    36.00
# LAM                                 63.00                    77.00
# LB                                  68.00                    75.00
# LCB                                 77.00                    71.00
# LCM                                 67.00                    80.00
# LDM                                 68.00                    79.00
# LF                                  62.00                    76.50
# LM                                  61.00                    75.00
# LS                                  79.00                    75.00
# LW                                  63.50                    78.00
# LWB                                 68.00                    74.75
# RAM                                 54.00                    81.00
# RB                                  68.25                    75.00
# RCB                                 78.00                    71.00
# RCM                                 66.00                    80.00
# RDM                                 71.00                    78.00
# RES                                 71.00                    74.00
# RF                                  52.00                    80.00
# RM                                  63.25                    76.00
# RS                                  76.00                    74.00
# RW                                  65.00                    76.00
# RWB                                 68.00                    75.00
# ST                                  78.00                    73.00
# SUB                                 72.00                    75.00
#
#                attacking_volleys  skill_dribbling  skill_curve  \
# team_position
# CAM                        72.00            80.00        78.25
# CB                         47.25            64.00        52.25
# CDM                        64.00            74.00        74.00
# CF                         78.00            86.00        79.00
# CM                         71.50            75.75        74.75
# GK                         16.00            18.00        19.00
# LAM                        72.00            80.00        74.00
# LB                         58.00            75.00        75.00
# LCB                        45.00            62.00        57.00
# LCM                        70.00            77.00        77.00
# LDM                        61.00            74.00        70.00
# LF                         68.00            78.50        72.50
# LM                         69.00            80.00        76.00
# LS                         75.25            78.00        70.50
# LW                         73.00            84.00        76.50
# LWB                        56.75            77.00        76.25
# RAM                        68.00            81.00        82.00
# RB                         58.00            75.00        70.00
# RCB                        44.00            59.00        50.75
# RCM                        67.75            78.00        74.00
# RDM                        63.00            73.00        70.00
# RES                        67.00            76.00        72.00
# RF                         71.50            83.00        79.50
# RM                         68.00            79.00        76.00
# RS                         75.00            77.25        72.00
# RW                         74.00            83.00        79.00
# RWB                        54.00            75.00        70.00
# ST                         76.00            75.00        68.25
# SUB                        67.00            76.00        72.00
#
#                skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# team_position
# CAM                        75.25               75.00               80.00
# CB                         51.50               71.25               69.50
# CDM                        74.00               78.00               77.75
# CF                         68.00               71.00               86.00
# CM                         75.00               79.00               78.75
# GK                         18.00               35.00               26.50
# LAM                        73.00               70.00               79.00
# LB                         66.25               70.25               76.00
# LCB                        50.25               69.00               67.00
# LCM                        74.00               78.00               79.75
# LDM                        69.00               76.50               76.00
# LF                         71.00               74.50               77.50
# LM                         70.00               70.00               79.00
# LS                         67.25               65.00               79.00
# LW                         73.00               71.00               82.00
# LWB                        66.00               69.00               76.75
# RAM                        75.00               73.00               79.00
# RB                         60.00               70.00               75.25
# RCB                        47.00               68.00               67.00
# LCB                          73.00              77.00
# LCM                          78.00              72.00
# LDM                          75.00              74.00
# LF                           78.50              61.50
# LM                           75.00              52.00
# LS                           78.00              42.25
# LW                           78.00              47.50
# LWB                          73.00              73.75
# RAM                          77.00              46.00
# RB                           73.00              75.00
# RCB                          73.00              78.00
# RCM                          78.00              73.75
# RDM                          77.00              75.25
# RES                          73.00              70.00
# RF                           78.50              57.50
# RM                           74.00              58.00
# RS                           77.00              40.25
# RW                           78.00              49.00
# RWB                          72.00              72.00
# ST                           77.00              42.00
# SUB                          74.00              71.00
#
#                defending_standing_tackle  defending_sliding_tackle  \
# team_position
# CAM                                60.25                     57.00
# CB                                 80.50                     78.00
# CDM                                77.00                     74.00
# CF                                 51.00                     42.00
# CM                                 75.00                     70.00
# GK                                 17.00                     16.00
# LAM                                53.00                     47.00
# LB                                 77.00                     76.00
# LCB                                79.00                     77.00
# LCM                                73.00                     70.00
# LDM                                74.00                     72.00
# LF                                 58.00                     54.50
# LM                                 52.00                     48.00
# LS                                 38.25                     33.25
# LW                                 44.00                     36.50
# LWB                                75.50                     75.75
# RAM                                53.00                     48.00
# RB                                 76.00                     75.25
# RCB                                79.00                     76.75
# RCM                                75.00                     71.75
# RDM                                76.25                     74.00
# RES                                73.00                     71.00
# RF                                 54.00                     51.00
# RM                                 59.00                     54.25
# RS                                 36.00                     32.00
# RW                                 49.00                     40.00
# RWB                                76.00                     75.00
# ST                                 38.00                     31.25
# SUB                                74.00                     72.00
#
#                goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# team_position
# CAM                         13.00                 13.00                13.00
# CB                          12.00                 12.00                14.00
# CDM                         14.00                 13.00                13.75
# CF                          14.00                 11.00                12.00
# CM                          14.75                 14.00                13.00
# GK                          79.00                 76.00                75.00
# LAM                         13.00                 15.00                13.00
# LB                          13.00                 13.00                13.00
# LCB                         13.00                 14.00                13.00
# LCM                         13.00                 14.00                13.00
# LDM                         13.00                 14.00                12.50
# LF                          14.00                 14.00                13.50
# LM                          13.00                 13.00                13.00
# LS                          12.00                 14.00                13.00
# LW                          13.50                 13.00                13.00
# LWB                         14.00                 14.75                12.00
# RAM                         11.00                 13.00                13.00
# RB                          13.00                 13.00                14.00
# RCB                         13.00                 13.00                14.00
# RCM                         13.00                 13.00                14.00
# RDM                         13.00                 14.00                14.00
# RES                         14.00                 13.00                13.00
# RF                          13.00                 12.00                13.50
# RM                          13.00                 14.00                13.00
# RS                          14.00                 14.00                13.00
# RW                          13.00                 13.00                13.00
# RWB                         12.00                 14.00                14.00
# ST                          14.00                 13.25                14.00
# SUB                         14.00                 14.00                14.00
#
#                goalkeeping_positioning
# team_position
# CAM                              13.25
# CB                               14.00
# CDM                              13.75
# CF                                8.00
# CM                               13.50
# GK                               78.00
# LAM                              15.00
# LB                               13.00
# LCB                              13.00
# LCM                              13.00
# LDM                              14.00
# LF                               12.50
# LM                               13.00
# LS                               12.25
# LW                               13.00
# LWB                              13.00
# RAM                              10.00
# RB                               13.00
# RCB                              13.00
# RCM                              14.00
# RDM                              15.00
# RES                              14.00
# RF                               12.50
# RM                               13.00
# RS                               13.00
# RW                               13.00
# RWB                              13.00
# ST                               13.00
# SUB                              14.00

# %%
len(df_n_playerp)
# Out:
# 29

# %%
# Podríamos decir que obtuvimos 395 grupos

# %%
df_n_playerp.columns
# Out:
# Index(['attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning'],
#       dtype='object')

# %%
# Planteamos un método de correlación que nos diga si están correlacionadas las variables
correlacion=df_n_playerp.corr()

# %%
# Seleccionamos aquellas variables que estén menos correlacionadas, de esta forma, en vez de formar una recta juntas,
# los datos representados por estas variables se encuentran lo más disperso posible
interesting_skill = correlacion['movement_balance']
interesting_skill= interesting_skill.abs().sort_values(ascending=True)
interesting_skill[1:6]
# Out:
# mentality_interceptions       0.030845
# defending_marking             0.030867
# defending_sliding_tackle      0.038686
# movement_reactions            0.044272
# attacking_heading_accuracy    0.126271
# Name: movement_balance, dtype: float64

# %%
# Graficamos...

data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores

#Elejimos dos variables, para esto elejimos dos números entre 0 y  de n_skills-1

skill_1='movement_balance'
skill_2='mentality_interceptions'

#skill_1=skills_ratings[4]
#skill_2=skills_ratings[21]



graf1 = go.Scatter(x=df_skills[skill_1], y=df_skills[skill_2],
                           mode='markers',
                        text=df_n.loc[:,'team_position'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Top players',
                      text=df_n.loc[bool_crack,'team_position'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf1,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>                            <div id="c8d857a1-a4bd-432c-829d-852cd05ebcb3" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8d857a1-a4bd-432c-829d-852cd05ebcb3")) {                    Plotly.newPlot(                        "c8d857a1-a4bd-432c-829d-852cd05ebcb3",                        [{"marker": {"size": 5}, "mode": "markers", "text": ["RW", "LW", "CAM", "GK", "LW", "RCM", "GK", "LCB", "RCM", "RW", "RW", "LCB", "ST", "GK", "GK", "RCM", "LCB", "ST", "LCB", "ST", "ST", "CDM", "LW", "RW", "LDM", "GK", "LW", "RM", "GK", "RCB", "GK", "GK", "GK", "LCM", "ST", "RCB", "LCM", "CAM", "LM", "LW", "LCB", "RW", "CDM", "LM", "CDM", "LCB", "CF", "LCB", "SUB", "LCB", "RCB", "LB", "CDM", "SUB", "LS", "SUB", "RCB", "LCB", "RCM", "SUB", "GK", "RB", "SUB", "CF", "RCM", "CDM", "LW", "RCB", "LCM", "RCM", "SUB", "ST", "ST", "SUB", "GK", "LCM", "RCB", "RCB", "RDM", "SUB", "LCM", "CDM", "LB", "RCB", "LCB", "RCM", "GK", "GK", "GK", "LS", "RCB", "SUB", "LB", "RES", "RB", "RAM", "ST", "CAM", "SUB", "SUB", "SUB", "LB", "LDM", "LB", "RS", "RM", "SUB", "RCM", "RM", "RF", "SUB", "GK", "SUB", "CAM", "LCB", "SUB", "LW", "SUB", "SUB", "LW", "RW", "RM", "GK", "CM", "LB", "GK", "CB", "RM", "RCB", "LCM", "GK", "GK", "CAM", "RCB", "LDM", "CAM", "SUB", "GK", "ST", "LCM", "SUB
# %%
# En el gráfico anterior se puede ver el agrupamiento por "team position". Si bien se diferencian dos grandes grupos,
# se puede ver que se diferencian grupos pequeños también.

# %% [markdown]
# Graficamos diferenciando los mejores jugadores y alguna característica de interés (Elegir)
#
# Se puede ubicar un jugador con la siguiente linea de comando, por ejemplo, Leo Messi:

# %%
#Gráfico 2

#Elegimos un jugador
recherche_joueur=df_n["short_name"]=='L. Messi' 
recherche_joueur2=df_n["short_name"]=='Cristiano Ronaldo' # acá podemos elegir otro 


bool_crack=df_n["overall"] > 85
bool_elecc=df_n["club"]=='FC Barcelona' 
#bool_elecc=df_n["Position"]=='GK' #arqueros
bool_no_crack=df_n["overall"]<86
bool_machinegun=df_n["short_name"]=='MachineGun'

#Elegir dos números entre 0 y  de n_skills-1
skill_1='movement_balance'  #6
skill_2='mentality_interceptions'  #25


palette=['navy','red','#A2D5F2','orange','green','pink']  

data=[]

n_crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Crack',
                      text=df_n.loc[bool_crack,'team_position'],
                      textfont=dict(family='sans serif',size=15,color='black'),
                      opacity=0.9,marker=dict(color=palette[2],size=7),mode='markers+text')#mode='markers+text'

n_no_crack =go.Scatter(x=df_skills.loc[bool_no_crack,skill_1], y=df_skills.loc[bool_no_crack,skill_2],name='Average player',
                         text=df_n.loc[bool_no_crack,'short_name'],
                         opacity=0.6,marker=dict(color=palette[1],size=3),mode='markers')
n_elecc=go.Scatter(x=df_skills.loc[bool_elecc,skill_1], y=df_skills.loc[bool_elecc,skill_2],name='Elección',
                         text=df_n.loc[bool_elecc,'short_name'],
                         opacity=0.6,marker=dict(color=palette[0],size=5),mode='markers')

n_machinegun =go.Scatter(x=df_skills.loc[bool_machinegun,skill_1], y=df_skills.loc[bool_machinegun,skill_2],name='Perfect player',
                           textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=0.6,marker=dict(color=palette[3],size=30),mode='markers+text')


joueur_recherche =go.Scatter(x=df_skills.loc[recherche_joueur,skill_1], y=df_skills.loc[recherche_joueur,skill_2],name='Messi',
                           text=df_n.loc[recherche_joueur,'team_position'],
                            textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=1,marker=dict(color=palette[4],size=40),mode='markers+text')

joueur_recherche2 =go.Scatter(x=df_skills.loc[recherche_joueur2,skill_1], y=df_skills.loc[recherche_joueur2,skill_2],name='Ronaldo',
                           text=df_n.loc[recherche_joueur2,'team_position'],
                            textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=1,marker=dict(color=palette[0],size=40),mode='markers+text')

data=[n_no_crack,n_elecc
      ,n_crack,n_machinegun,joueur_recherche,joueur_recherche2]

layout = go.Layout(title="Fifa Players",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>                            <div id="9c7cda10-7c4d-4f9e-8670-f3a6294de0f7" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c7cda10-7c4d-4f9e-8670-f3a6294de0f7")) {                    Plotly.newPlot(                        "9c7cda10-7c4d-4f9e-8670-f3a6294de0f7",                        [{"marker": {"color": "red", "size": 3}, "mode": "markers", "name": "Average player", "opacity": 0.6, "text": ["M. de Ligt", "G. Donnarumma", "F. de Jong", "R. Varane", "N. S\u00fcle", "S. Milinkovi\u0107-Savi\u0107", "Rodri", "Sa\u00fal", "Fabinho", "A. Robertson", "J. Gim\u00e9nez", "C. Lenglet", "Bruno Fernandes", "A. Lopes", "P. Gul\u00e1csi", "R. B\u00fcrki", "R. Lukaku", "K. Manolas", "Neto", "D. Alaba", "M. Icardi", "Carvajal", "H. Ziyech", "Z. Ibrahimovi\u0107", "A. G\u00f3mez", "G. Higua\u00edn", "B. Matuidi", "G. Bale", "Marcelo", "A. Witsel", "Alex Sandro", "Iago Aspas", "Koke", "J. Rodr\u00edguez", "Allan", "J. Sancho", "K. Havertz", "O. Demb\u00e9l\u00e9", "Kepa", "Jo\u00e3o Cancelo", "D. Alli", "L. Hern\u00e1ndez", "Arthur", "M. Depay", "L. Goretzka", "J. Brandt", "K. Coman", "S. Gnabry", "N. Fekir", "B. Leno", "Luis Alberto", "Alex Telles", "J. Pavlenka", "S. de Vrij", "Felipe Anderson", "Pepe", "Jo\u00e3o Moutinho", "S. Ruffier", "S. Sirigu", "M. Ham\u0161\u00edk", "Sokratis", "Lucas Leiva", "M. \u00d6zil", "Javi Mart\u00ednez", "Y. Sommer", "E. D\u017eeko", "G. Wijnaldum", "I. Peri\u0161i\u0107", "M. Mand\u017euki\u0107", "A. Vidal", "J. Boateng", "Azpilicueta", "Jos\u00e9 Callej\u00f3n", "I. G\u00fcndo\u011fan", "Paulinho", "K. Walker", "Canales", "Douglas Costa", "Pizzi", "D. Tadi\u0107", "J. Ili\u010di\u0107", "R. Mahrez", "E. Vi\u0161\u0107a", "Felipe", "Fabi\u00e1n", "A. Romagnoli", "G. Lo Celso", "T. Alexander-Arnold", "L. Jovi\u0107", "A. Milik", "A. Martial", "Anderson Talisca", "J. Tah", "C. Tolisso", "Pau L\u00f3pez", "Gon\u00e7alo Guedes", "N. P\u00e9p\u00e9", "M. Akanji", "M. Rashford", "J. Stones", "A. Rabiot", "Grimaldo", "T. Werner", "T. Lemar", "D. S\u00e1nchez", "Marco Asensio", "L. Digne", "J. Draxler", "J. Pickford", "Y. Carrasco", "Borja Iglesias", "K. Casteels", "W. Zaha", "Paco Alc\u00e1cer", "Morata", "S. Haller", "William Carvalho", "F. Bernardeschi", "D. Djen\u00e9", "Oscar", "K. Trapp", "Bartra", "Pablo Sarabia", "J. Cillessen", "Lucas Moura", "F. Thauvin", "Jorginho", "G. Buffon", "Casillas", "R. Jarstein", "V. Kompany", "Ra\u00fal Albiol", "F. Quagliarella", "K. Schmeichel", "Falcao", "Miranda", "C. Vela", "E. Garay", "Rui Patr\u00edcio", "R. Nainggolan", "E. Banega", "Diego Costa", "S. Khedira", "David Luiz", "M. Kruse", "J. Henderson", "G. Sigur\u00f0sson", "A. Ramsey", "Illarramendi", "D. Blind", "L. Hr\u00e1deck\u00fd", "N. Otamendi", "J. Cuadrado", "I. Gueye", "K. Kampl", "Rodrigo", "C. Ar\u00e1nguiz", "W. Ben Yedder", "F. Acerbi", "Danilo Pereira", "A. Kramari\u0107", "Louri Beretta", "Josu\u00e9 Chiamulera", "Ronaldo Cabrais", "Oyarzabal", "L. Bailey", "Gabriel Jesus", "M. Kova\u010di\u0107", "A. Belotti", "T. Strakosha", "N. Ke\u00efta", "L. Torreira", "R\u00faben Neves", "P. Kimpembe", "S. Bergwijn", "A. Onana", "N\u00e9lson Semedo", "A. Areola", "M. Perin", "D. Rugani", "A. Correa", "I\u00f1aki Williams", "H. Lozano", "Gelson Martins", "B. Lecomte", "T. Partey", "K. Demirbay", "J. Matip", "Suso", "S. Savi\u0107", "A. R\u00fcdiger", "Pacheco", "Ricardo Pereira", "N. Tagliafico", "David Soria", "Sergio Asenjo", "Muniain", "M. G\u00f6tze", "T. Delaney", "O. Baumann", "Willian Jos\u00e9", "Sergi Roberto", "N. Schulz", "K. Volland", "Nacho Fern\u00e1ndez", "Gabriel Paulista", "J. Roussillon", "H. Maguire", "T. Hazard", "E. Forsberg", "F. Kosti\u0107", "M. Politano", "Rafa", "Pepe Reina", "D. De Rossi", "Aduriz", "Jes\u00fas Navas", "Santi Cazorla", "H. He ...

# %%
set(df_n.team_position)
# Out:
# {'CAM',
#  'CB',
#  'CDM',
#  'CF',
#  'CM',
#  'GK',
#  'LAM',
#  'LB',
#  'LCB',
#  'LCM',
#  'LDM',
#  'LF',
#  'LM',
#  'LS',
#  'LW',
#  'LWB',
#  'RAM',
#  'RB',
#  'RCB',
#  'RCM',
#  'RDM',
#  'RES',
#  'RF',
#  'RM',
#  'RS',
#  'RW',
#  'RWB',
#  'ST',
#  'SUB',
#  nan}

# %% [markdown]
# **Identifiquemos algunos jugadores por nombre**

# %%
print(df_n.loc[0:43,"short_name"])
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             Neymar Jr
# 3              J. Oblak
# 4             E. Hazard
# 5          K. De Bruyne
# 6         M. ter Stegen
# 7           V. van Dijk
# 8             L. Modrić
# 9              M. Salah
# 10            K. Mbappé
# 11         K. Koulibaly
# 12              H. Kane
# 13              Alisson
# 14               De Gea
# 15             N. Kanté
# 16         G. Chiellini
# 17            S. Agüero
# 18         Sergio Ramos
# 19            L. Suárez
# 20       R. Lewandowski
# 21      Sergio Busquets
# 22         A. Griezmann
# 23            P. Dybala
# 24             P. Pogba
# 25              Ederson
# 26          R. Sterling
# 27           C. Eriksen
# 28          T. Courtois
# 29                Piqué
# 30        S. Handanovič
# 31             M. Neuer
# 32            H. Lloris
# 33          David Silva
# 34            E. Cavani
# 35             D. Godín
# 36             T. Kroos
# 37              M. Reus
# 38        P. Aubameyang
# 39              S. Mané
# 40           A. Laporte
# 41       Bernardo Silva
# 42             Casemiro
# 43               H. Son
# Name: short_name, dtype: object
