# %% [markdown]
# <center>
# <img src="FIFA-19-Background-1-768x401.jpg" />
#
# ## Aprendizaje No Supervisado 2020 DiploDatos
#     Laura Alonso Alemany, Ana Georgina Flesia y Valeria Rulloni
# ## Agrupamiento con el FIFA 2019 dataset
#
# Material basado en notas de Ana Georgina Flesia bajo los términos y condiciones de la licencia [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/), a su vez basado de material de [SilveMel](https://www.kaggle.com/karangadiya/fifa19/downloads/data.csv/comments) y otros.

# %% [markdown]
# ### Indice de temas
# 1. [Inicialización del entorno](#1.-Inicialización-del-entorno)
# 2. [Exploración de la Base](#2.-Exploración-de-la-base)
# 3. [Preparación de los datos](#3.-Preparación-de-los-datos)
# 4. [Clustering Visual](#3.-Exploratorio-Visual-para-Clustering)

# %% [markdown]
# ## 1.-Inicialización-del-entorno

# %% [markdown]
# **Empezamos cargando algunas herramientas para cargar los datos y manipularlos.**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)
import itertools
import warnings
warnings.filterwarnings("ignore")
import io

# %% [markdown]
# **Para visualización usaremos principalmente plotly, también seaborn y matplotlib.**

# %%
from plotly.offline import init_notebook_mode, plot,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2.-Exploración-de-la-base

# %% [markdown]
# **Cargamos los datos bajados de la database de [Kaggle](https://www.kaggle.com/karangadiya/fifa19) (https://www.kaggle.com/karangadiya/fifa19) como 'data.csv'.**

# %%
df=pd.read_csv("players_20.csv")
df.head(4)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 3        188         87    Slovenia      Atlético Madrid       91         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 3   77500000    125000               GK          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# 1                         5          4            5       High/Low
# 2                         5          5            5    High/Medium
# 3                         3          3            1  Medium/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
#
#    attacking_volleys  skill_dribbling  ...  movement_acceleration  \
# 0                 88               97  ...                     91
# 1                 87               89  ...                     89
# 2                 87               96  ...                     94
# 3                 13               12  ...                     43
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                    89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
#
# [4 rows x 104 columns]

# %%
df.tail(4)
# Out:
#        sofifa_id                                         player_url  \
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  overall  potential  \
# 18274    China PR               Shanghai SIPG FC       48         56
# 18275    China PR         Hebei China Fortune FC       48         56
# 18276    China PR  Shanghai Greenland Shenhua FC       48         54
# 18277    China PR         Hebei China Fortune FC       48         51
#
#        value_eur  wage_eur player_positions preferred_foot  \
# 18274      40000      2000               CB          Right
# 18275      40000      1000               CM          Right
# 18276      40000      1000               CM          Right
# 18277      40000      2000               CM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 18274                         1          2            2  Medium/Medium
# 18275                         1          2            2     Low/Medium
# 18276                         1          2            2        Low/Low
# 18277                         1          3            2  Medium/Medium
#
#       body_type real_face  release_clause_eur player_tags team_position  \
# 18274    Normal        No             72000.0         NaN           SUB
# 18275      Lean        No             70000.0         NaN           SUB
# 18276      Lean        No             70000.0         NaN           SUB
# 18277    Normal        No                 NaN         NaN           SUB
#
#        team_jersey_number      loaned_from      joined  contract_valid_until  \
# 18274                31.0              NaN  2019-02-01                2022.0
# 18275                38.0              NaN  2019-01-01                2019.0
# 18276                33.0              NaN  2019-02-01                2022.0
# 18277                37.0  Tianjin TEDA FC         NaN                2019.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 18274             NaN                   NaN  58.0      24.0     33.0
# 18275             NaN                   NaN  54.0      35.0     44.0
# 18276             NaN                   NaN  59.0      35.0     47.0
# 18277             NaN                   NaN  60.0      32.0     51.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 18274       35.0       48.0    48.0        NaN          NaN         NaN
# 18275       45.0       48.0    51.0        NaN          NaN         NaN
# 18276       47.0       45.0    52.0        NaN          NaN         NaN
# 18277       45.0       47.0    55.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning player_traits  \
# 18274          NaN       NaN             NaN           NaN
# 18275          NaN       NaN             NaN           NaN
# 18276          NaN       NaN             NaN           NaN
# 18277          NaN       NaN             NaN           NaN
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 18274                  24                   20                          42
# 18275                  32                   33                          49
# 18276                  39                   34                          47
# 18277                  44                   30                          48
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  ...  \
# 18274                       43                 28               32  ...
# 18275                       53                 32               40  ...
# 18276                       54                 28               42  ...
# 18277                       58                 25               40  ...
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 18274                     55                     61                43
# 18275                     55                     54                52
# 18276                     55                     63                55
# 18277                     54                     64                52
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 18274                  41                76                33             72
# 18275                  52                57                48             60
# 18276                  54                59                46             61
# 18277                  49                71                41             64
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 18274             55              44                20                    42
# 18275             50              51                26                    50
# 18276             42              55                28                    57
# 18277             40              61                30                    54
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 18274                       49                     23                25
# 18275                       45                     38                38
# 18276                       49                     31                48
# 18277                       47                     29                52
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 18274                   37                   35                 42
# 18275                   36                   39                 46
# 18276                   36                   40                 39
# 18277                   38                   42                 52
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 18274                         53                        57
# 18275                         52                        46
# 18276                         44                        54
# 18277                         42                        48
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 18274                  13                     6                   14
# 18275                   7                     8                   10
# 18276                  14                     9                   13
# 18277                   8                    12                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 18274                       11                     9  33+2  33+2  33+2  33+2
# 18275                        6                    14  43+2  43+2  43+2  43+2
# 18276                       13                    13  43+2  43+2  43+2  45+2
# 18277                        9                    10  42+2  42+2  42+2  44+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 18274  32+2  32+2  32+2  33+2  33+2  33+2  33+2  35+2  36+2  36+2  36+2  35+2
# 18275  43+2  43+2  43+2  43+2  44+2  44+2  44+2  45+2  46+2  46+2  46+2  45+2
# 18276  44+2  44+2  44+2  45+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
# 18277  43+2  43+2  43+2  44+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 18274  44+2  43+2  43+2  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  47+2  49+2  49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  49+2  49+2  49+2  48+2  48+2  50+2  50+2  50+2  48+2
#
# [4 rows x 104 columns]

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print(df.columns[:77])
print(len(df.columns))
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning'],
#       dtype='object')
# 104

# %% [markdown]
# La variable **'Overall'** se calcula usando otras variables de desempeño del jugador (skills_ratings).
#
# La variable 'Overall' es discreta, así como las otras de desempeño según habilidad ('Crossing',
#        'Finishing', 'HeadingAccuracy', etc.), tomando valores enteros entre 0 y 100
#
# Miramos ahora los mejores jugadores por posicion, usando las variables 'Overall' y 'Position'.

# %% [markdown]
# **Realizamos el histograma de la variable "Overall" (Desempeño global)**

# %%
df['overall'].hist(bins = 20)

# %%
best_players_per_position=df.iloc[df.groupby(df['team_position'])['overall'].idxmax()][['team_position','short_name','overall']]
best_players_per_position
# Out:
#     team_position           short_name  overall
# 2             CAM            Neymar Jr       92
# 126            CB           S. de Vrij       84
# 21            CDM      Sergio Busquets       89
# 46             CF           K. Benzema       87
# 123            CM         Luis Alberto       84
# 3              GK             J. Oblak       91
# 306           LAM               Taison       82
# 51             LB           Jordi Alba       87
# 7             LCB          V. van Dijk       90
# 33            LCM          David Silva       88
# 24            LDM             P. Pogba       88
# 259            LF          K. Demirbay       82
# 38             LM        P. Aubameyang       88
# 54             LS           L. Insigne       87
# 1              LW    Cristiano Ronaldo       93
# 483           LWB       M. Halstenberg       80
# 95            RAM            H. Ziyech       85
# 61             RB           J. Kimmich       86
# 29            RCB                Piqué       88
# 5             RCM         K. De Bruyne       91
# 78            RDM  S. Milinković-Savić       85
# 93            RES            M. Icardi       85
# 109            RF           K. Havertz       84
# 27             RM           C. Eriksen       88
# 104            RS           Iago Aspas       85
# 0              RW             L. Messi       94
# 476           RWB         P. Kadeřábek       80
# 12             ST              H. Kane       89
# 48            SUB           D. Mertens       87

# %%
pd.DataFrame(df.team_position.value_counts().sort_index())
# Out:
#      team_position
# CAM            311
# CB             100
# CDM            181
# CF              14
# CM              76
# GK             662
# LAM             23
# LB             560
# LCB            660
# LCM            411
# LDM            242
# LF              19
# LM             398
# LS             195
# LW             162
# LWB             58
# RAM             23
# RB             560
# RCB            660
# RCM            411
# RDM            244
# RES           2958
# RF              19
# RM             399
# RS             195
# RW             161
# RWB             58
# ST             458
# SUB           7820

# %%
club_avg_overall=df.groupby("club")["overall"].mean().reset_index().sort_values("overall",ascending=False)
club_avg_overall.head(8)
# Out:
#                   club    overall
# 226  FC Bayern München  81.304348
# 505        Real Madrid  80.121212
# 350           Juventus  80.060606
# 650            Uruguay  78.608696
# 224       FC Barcelona  78.363636
# 407             Mexico  78.000000
# 426        Netherlands  78.000000
# 166           Colombia  78.000000

# %% [markdown]
# ## 2.-Preparación-de-los-datos

# %% [markdown]
# **Retiramos jugadores con bajo Desempeño global ("Overall"), reducimos el tamaño de la base**
#
# **y consideramos Variables de desempeño por habilidad (skills_ratings)**

# %%
n=10000 #cantidad de jugadores a considerar

df_n=df.loc[:n] #se reduce la base a los n primeros jugadores

df_n=df_n[(df_n['overall']>70)]

skills_ratings = ['attacking_crossing',
       'attacking_finishing', 'attacking_heading_accuracy',
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
       'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
       'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
       'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking', 'defending_standing_tackle',
       'defending_sliding_tackle', 'goalkeeping_diving',
       'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning']

print(len(skills_ratings), 'variables numéricas de desempeño según habilidad')
# Out:
# 33 variables numéricas de desempeño según habilidad

# %% [markdown]
# **Se crea el jugador perfecto para ver a donde se ubica en nuestra visualización**

# %%
MachineGunDict={'short_name':'MachineGun','overall':99}
for skills in skills_ratings:
    MachineGunDict[skills]=99
    
df_n=df_n.append(MachineGunDict,ignore_index=True)

# %%
df_skills=df_n[skills_ratings] #base, sólo con desempeños según habilidad (numéricas)

# %%
df_skills.head(4)
# Out:
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                  88                   95                          70
# 1                  84                   94                          89
# 2                  87                   87                          62
# 3                  13                   11                          15
#
#    attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 0                       92                 88               97           93
# 1                       83                 87               89           81
# 2                       87                 87               96           88
# 3                       43                 13               12           13
#
#    skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0                 94                  92                  96
# 1                 76                  77                  92
# 2                 87                  81                  95
# 3                 14                  40                  30
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                     91                     84                93
# 1                     89                     91                87
# 2                     94                     89                96
# 3                     43                     60                67
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                  95                95                86             68
# 1                  96                71                95             95
# 2                  92                84                80             61
# 3                  88                49                59             78
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0             75              68                94                    48
# 1             85              78                93                    63
# 2             81              49                84                    51
# 3             41              78                12                    34
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90

# %%
df_skills.isna().sum()
# Out:
# attacking_crossing            0
# attacking_finishing           0
# attacking_heading_accuracy    0
# attacking_short_passing       0
# attacking_volleys             0
# skill_dribbling               0
# skill_curve                   0
# skill_fk_accuracy             0
# skill_long_passing            0
# skill_ball_control            0
# movement_acceleration         0
# movement_sprint_speed         0
# movement_agility              0
# movement_reactions            0
# movement_balance              0
# power_shot_power              0
# power_jumping                 0
# power_stamina                 0
# power_strength                0
# power_long_shots              0
# mentality_aggression          0
# mentality_interceptions       0
# mentality_positioning         0
# mentality_vision              0
# mentality_penalties           0
# mentality_composure           0
# defending_marking             0
# defending_standing_tackle     0
# defending_sliding_tackle      0
# goalkeeping_diving            0
# goalkeeping_handling          0
# goalkeeping_kicking           0
# goalkeeping_positioning       0
# dtype: int64

# %% [markdown]
# ## 3.-Exploratorio-Visual-para-Clustering

# %% [markdown]
# **Visualizamos los datos de a dos variables numéricas**
#
# **Consigna de trabajo en grupo: buscar agrupamiento de datos usando las variables en skill_ratings de a pares**

# %%
df_n.head()
# Out:
#    sofifa_id                                         player_url  \
# 0   158023.0  https://sofifa.com/player/158023/lionel-messi/...
# 1    20801.0  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2   190871.0  https://sofifa.com/player/190871/neymar-da-sil...
# 3   200389.0  https://sofifa.com/player/200389/jan-oblak/20/...
# 4   183277.0  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name   age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior  27.0  1992-02-05
# 3           J. Oblak                            Jan Oblak  26.0  1993-01-07
# 4          E. Hazard                          Eden Hazard  28.0  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0      170.0       72.0   Argentina         FC Barcelona       94       94.0
# 1      187.0       83.0    Portugal             Juventus       93       93.0
# 2      175.0       68.0      Brazil  Paris Saint-Germain       92       92.0
# 3      188.0       87.0    Slovenia      Atlético Madrid       91       93.0
# 4      175.0       74.0     Belgium          Real Madrid       91       91.0
#
#      value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000.0  565000.0       RW, CF, ST           Left
# 1   58500000.0  405000.0           ST, LW          Right
# 2  105500000.0  290000.0          LW, CAM          Right
# 3   77500000.0  125000.0               GK          Right
# 4   90000000.0  470000.0           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                       5.0        4.0          4.0     Medium/Low
# 1                       5.0        4.0          5.0       High/Low
# 2                       5.0        5.0          5.0    High/Medium
# 3                       3.0        3.0          1.0  Medium/Medium
# 4                       4.0        4.0          4.0    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  ...  movement_acceleration  \
# 0                 88               97  ...                     91
# 1                 87               89  ...                     89
# 2                 87               96  ...                     94
# 3                 13               12  ...                     43
# 4                 83               95  ...                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
# 4                         27                        22                  11
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
# 4                    12                    6                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                   8.0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                  11.0  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                  11.0  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                  89.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                   8.0  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
# 4  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
df_n.drop(skills_ratings, axis=1).columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'goalkeeping_reflexes', 'ls', 'st',
#        'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm',
#        'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
#        'rcb', 'rb'],
#       dtype='object')

# %%
df_n.drop(skills_ratings, axis=1).head()
# Out:
#    sofifa_id                                         player_url  \
# 0   158023.0  https://sofifa.com/player/158023/lionel-messi/...
# 1    20801.0  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2   190871.0  https://sofifa.com/player/190871/neymar-da-sil...
# 3   200389.0  https://sofifa.com/player/200389/jan-oblak/20/...
# 4   183277.0  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name   age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior  27.0  1992-02-05
# 3           J. Oblak                            Jan Oblak  26.0  1993-01-07
# 4          E. Hazard                          Eden Hazard  28.0  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0      170.0       72.0   Argentina         FC Barcelona       94       94.0
# 1      187.0       83.0    Portugal             Juventus       93       93.0
# 2      175.0       68.0      Brazil  Paris Saint-Germain       92       92.0
# 3      188.0       87.0    Slovenia      Atlético Madrid       91       93.0
# 4      175.0       74.0     Belgium          Real Madrid       91       91.0
#
#      value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000.0  565000.0       RW, CF, ST           Left
# 1   58500000.0  405000.0           ST, LW          Right
# 2  105500000.0  290000.0          LW, CAM          Right
# 3   77500000.0  125000.0               GK          Right
# 4   90000000.0  470000.0           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                       5.0        4.0          4.0     Medium/Low
# 1                       5.0        4.0          5.0       High/Low
# 2                       5.0        5.0          5.0    High/Medium
# 3                       3.0        3.0          1.0  Medium/Medium
# 4                       4.0        4.0          4.0    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  goalkeeping_reflexes  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                   8.0
# 1  Long Throw-in, Selfish, Argues with Officials,...                  11.0
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  11.0
# 3                         Flair, Acrobatic Clearance                  89.0
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                   8.0
#
#      ls    st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm  \
# 0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2
# 1  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3
# 2  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3
#
#     lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 0  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2
# 1  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3
# 2  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3
#
#     rcb    rb
# 0  52+2  63+2
# 1  53+3  61+3
# 2  46+3  61+3
# 3   NaN   NaN
# 4  49+3  61+3

# %%
df_n[skills_ratings].describe()
# Out:
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# count         4757.000000          4757.000000                 4757.000000
# mean            58.262771            54.057179                   59.449022
# std             19.057687            20.483703                   18.241367
# min              6.000000             5.000000                    7.000000
# 25%             49.000000            40.000000                   52.000000
# 50%             65.000000            60.000000                   64.000000
# 75%             72.000000            70.000000                   72.000000
# max             99.000000            99.000000                   99.000000
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# count              4757.000000        4757.000000      4757.000000
# mean                 67.698760          51.823839        64.320790
# std                  13.742444          19.371476        18.872155
# min                  11.000000           5.000000         7.000000
# 25%                  66.000000          38.000000        60.000000
# 50%                  71.000000          56.000000        71.000000
# 75%                  75.000000          67.000000        76.000000
# max                  99.000000          99.000000        99.000000
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# count  4757.000000        4757.000000         4757.000000         4757.000000
# mean     57.134959          51.144839           61.889847           67.685306
# std      19.546689          19.273338           14.419714           16.130121
# min       6.000000           4.000000            9.000000            5.000000
# 25%      46.000000          37.000000           57.000000           66.000000
# 50%      63.000000          54.000000           65.000000           72.000000
# 75%      72.000000          67.000000           72.000000           76.000000
# max      99.000000          99.000000           99.000000           99.000000
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# count            4757.000000            4757.000000       4757.000000
# mean               67.452596              67.633172         67.712214
# std                14.561249              14.222689         14.253701
# min                15.000000              16.000000         14.000000
# 25%                59.000000              60.000000         60.000000
# 50%                69.000000              70.000000         70.000000
# 75%                78.000000              77.000000         77.000000
# max                99.000000              99.000000         99.000000
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# count         4757.000000       4757.000000       4757.000000    4757.000000
# mean            71.824679         65.586294         67.830986      68.633593
# std              5.584465         14.534318         11.524375      11.849742
# min             54.000000         20.000000         15.000000      29.000000
# 25%             68.000000         57.000000         60.000000      62.000000
# 50%             72.000000         68.000000         70.000000      70.000000
# 75%             75.000000         76.000000         76.000000      77.000000
# max             99.000000         99.000000         99.000000      99.000000
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# count    4757.000000     4757.000000       4757.000000           4757.000000
# mean       69.149674       69.867774         56.995796             64.027328
# std        14.882321       11.546919         19.788059             17.007064
# min        13.000000       26.000000          5.000000             11.000000
# 25%        65.000000       63.000000         47.000000             55.000000
# 50%        72.000000       71.000000         64.000000             69.000000
# 75%        78.000000       78.000000         71.000000             76.000000
# max        99.000000       99.000000         99.000000             99.000000
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# count              4757.000000            4757.000000       4757.000000
# mean                 54.128232              58.877234         62.899727
# std                  22.016307              20.533539         13.361799
# min                   7.000000               3.000000         10.000000
# 25%                  33.000000              50.000000         56.000000
# 50%                  64.000000              67.000000         66.000000
# 75%                  73.000000              73.000000         73.000000
# max                  99.000000              99.000000         99.000000
#
#        mentality_penalties  mentality_composure  defending_marking  \
# count          4757.000000          4757.000000        4757.000000
# mean             55.392684            69.299138          53.779062
# std              16.532943             8.903975          21.563590
# min               9.000000            17.000000           7.000000
# 25%              45.000000            65.000000          35.000000
# 50%              59.000000            70.000000          62.000000
# 75%              68.000000            75.000000          72.000000
# max              99.000000            99.000000          99.000000
#
#        defending_standing_tackle  defending_sliding_tackle  \
# count                4757.000000               4757.000000
# mean                   53.898676                 51.014085
# std                    23.421518                 23.560830
# min                     7.000000                  8.000000
# 25%                    32.000000                 27.000000
# 50%                    65.000000                 61.000000
# 75%                    74.000000                 72.000000
# max                    99.000000                 99.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count         4757.000000           4757.000000          4757.000000
# mean            16.657347             16.443347            16.251839
# std             19.244976             18.344544            17.700173
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             99.000000             99.000000            99.000000
#
#        goalkeeping_positioning
# count              4757.000000
# mean                 16.569687
# std                  18.832135
# min                   1.000000
# 25%                   8.000000
# 50%                  11.000000
# 75%                  14.000000
# max                  99.000000

# %%
# Agrupamos de acuerdo a la posición de los jugadores, y nos fijamos donde se ubican el %75 de los datos 
# de nuestras variables, que sería la mayoría de los datos.
df_n_playerp=df_n.groupby(by=['player_positions'])[skills_ratings].quantile(.75)
df_n_playerp
# Out:
#                   attacking_crossing  attacking_finishing  \
# player_positions
# CAM                            73.50                72.00
# CAM, CDM                       71.75                67.00
# CAM, CDM, CM                   69.00                72.75
# CAM, CF                        74.00                73.00
# CAM, CF, CM                    68.25                70.00
# CAM, CF, RW                    72.25                68.50
# CAM, CF, ST                    79.50                78.00
# CAM, CM                        74.00                71.00
# CAM, CM, CDM                   71.50                68.50
# CAM, CM, CF                    76.00                77.00
# CAM, CM, LM                    74.00                70.00
# CAM, CM, LW                    81.00                78.00
# CAM, CM, RM                    77.75                70.75
# CAM, CM, RW                    70.00                71.50
# CAM, CM, ST                    63.00                74.00
# CAM, LM                        74.00                70.00
# CAM, LM, CF                    65.00                69.00
# CAM, LM, CM                    75.00                72.00
# CAM, LM, LW                    73.00                72.00
# CAM, LM, RM                    77.00                70.00
# CAM, LM, RW                    69.00                71.00
# CAM, LM, ST                    78.00                78.00
# CAM, LW                        77.25                71.50
# CAM, LW, CM                    69.00                66.00
# CAM, LW, RW                    63.50                68.00
# CAM, LW, ST                    77.00                80.00
# CAM, RB                        76.00                58.00
# CAM, RM                        74.00                72.00
# CAM, RM, CF                    75.75                71.00
# CAM, RM, CM                    71.50                68.50
# CAM, RM, LM                    74.00                71.00
# CAM, RM, RB                    72.00                64.00
# CAM, RM, RW                    76.50                77.00
# CAM, RM, ST                    69.00                68.75
# CAM, RW                        80.50                76.00
# CAM, RW, CF                    68.00                60.00
# CAM, RW, CM                    63.25                66.00
# CAM, RW, LW                    78.00                72.00
# CAM, RW, RM                    77.00                64.00
# CAM, ST                        71.00                76.00
# CAM, ST, CDM                   68.00                70.00
# CAM, ST, CF                    67.00                67.00
# CAM, ST, LM                    66.00                71.00
# CAM, ST, LW                    65.00                69.00
# CAM, ST, RM                    70.50                69.50
# CAM, ST, RW                    71.75                72.00
# CB                             52.00                42.00
# CB, CDM                        57.00                49.00
# CB, CDM, CM                    48.00                47.50
# CB, CDM, LB                    70.00                50.00
# CB, CDM, RB                    67.00                38.50
# CB, CM, CDM                    49.00                29.00
# CB, LB                         68.00                49.00
# CB, LB, CDM                    21.00                23.00
# CB, LB, RB                     69.25                44.25
# CB, LWB                        69.50                47.00
# CB, RB                         67.75                41.75
# CB, RB, LB                     67.00                41.00
# CB, RB, RM                     69.00                49.00
# CB, RWB, RB                    68.00                50.00
# CDM                            64.00                59.00
# CDM, CAM, CM                   71.00                67.25
# CDM, CAM, LM                   66.00                70.00
# CDM, CB                        59.75                52.75
# CDM, CB, CM                    62.50                55.50
# CDM, CB, LB                    80.00                62.00
# CDM, CB, RB                    39.00                45.00
# CDM, CM                        67.00                60.00
# CDM, CM, CAM                   69.00                58.00
# CDM, CM, CB                    65.75                59.75
# CDM, CM, LB                    66.50                42.00
# CDM, CM, LM                    68.00                63.00
# CDM, CM, RB                    71.50                60.00
# CDM, CM, RM                    65.00                61.00
# CDM, LB                        72.25                48.75
# CDM, LB, CM                    68.25                53.25
# CDM, RB                        48.00                55.00
# CDM, RB, RM                    51.00                51.00
# CDM, RM                        71.00                53.00
# CDM, RWB                       52.00                48.00
# CF                             74.00                79.00
# CF, CAM                        70.50                75.00
# CF, CAM, CM                    82.00                78.00
# CF, CAM, LM                    60.75                72.00
# CF, CAM, ST                    76.00                72.25
# CF, CM                         75.00                77.00
# CF, CM, LW                     77.00                70.00
# CF, LM                         81.00                86.00
# CF, LM, LW                     78.00                78.00
# CF, LW                         69.25                75.50
# CF, LW, CAM                    78.75                75.00
# CF, LW, RW                     74.00                76.00
# CF, LW, ST                     86.00                77.00
# CF, RM, LM                     75.00                82.00
# CF, RW                         78.00                75.00
# CF, RW, LW                     75.00                74.00
# CF, RW, RM                     56.00                80.00
# CF, RW, ST                     70.00                77.00
# CF, ST                         78.00                84.00
# CF, ST, CAM                    72.50                80.25
# CF, ST, LW                     83.00                89.00
# CF, ST, RM                     70.50                80.25
# CM                             73.00                67.00
# CM, CAM                        73.00                68.00
# CM, CAM, CDM                   73.00                68.00
# CM, CAM, CF                    78.00                80.00
# CM, CAM, LM                    73.00                72.00
# CM, CAM, RM                    69.00                69.50
# CM, CAM, RW                    82.00                72.00
# CM, CAM, ST                    56.00                70.00
# CM, CB                         75.00                66.00
# CM, CB, CAM                    57.00                59.00
# CM, CDM                        72.00                66.00
# CM, CDM, CAM                   70.00                68.00
# CM, CDM, CB                    68.00                66.00
# CM, CDM, CF                    71.00                70.00
# CM, CDM, LB                    67.00                57.00
# CM, CDM, LM                    75.00                70.00
# CM, CDM, LW                    71.00                59.50
# CM, CDM, RB                    71.25                58.50
# CM, CDM, RM                    69.50                69.00
# CM, CDM, RWB                   63.00                61.00
# CM, CF                         69.00                57.00
# CM, CF, CAM                    68.00                70.00
# CM, LB                         72.00                62.00
# CM, LM                         72.25                67.25
# CM, LM, CAM                    76.50                75.50
# CM, LM, CDM                    73.25                69.50
# CM, LM, LB                     75.50                64.75
# CM, LM, RB                     73.00                55.00
# CM, LM, RM                     77.50                74.25
# CM, LW                         75.50                70.00
# CM, LW, RW                     73.00                72.00
# CM, LWB                        74.50                69.00
# CM, LWB, LM                    74.00                72.00
# CM, RB                         71.25                62.50
# CM, RB, RM                     81.00                75.00
# CM, RM                         69.75                67.75
# CM, RM, CAM                    71.00                71.25
# CM, RM, CDM                    74.75                64.75
# CM, RM, RB                     73.00                60.00
# CM, RW                         65.00                62.00
# CM, RW, CAM                    72.00                69.25
# CM, RWB, RM                    63.00                65.00
# CM, ST                         61.00                73.00
# GK                             18.00                15.00
# LB                             79.00                57.00
# LB, CAM, LM                    75.00                68.00
# LB, CB                         75.00                56.00
# LB, CB, CDM                    61.00                51.00
# LB, CB, LM                     76.00                58.00
# LB, CB, LWB                    67.25                40.00
# LB, CDM                        76.25                64.75
# LB, CM                         71.50                58.75
# LB, CM, LM                     67.00                45.00
# LB, LM                         78.00                60.00
# LB, LM, CAM                    75.00                60.00
# LB, LM, LWB                    79.50                64.00
# LB, LM, RM                     71.00                70.00
# LB, LW                         66.00                56.00
# LB, LWB                        77.75                55.00
# LB, LWB, CDM                   72.00                36.00
# LB, LWB, LM                    76.00                56.50
# LB, LWB, RB                    68.00                30.00
# LB, RB                         75.50                59.75
# LB, RB, CB                     72.50                58.00
# LB, RB, RM                     75.00                50.00
# LB, RM                         76.50                63.75
# LB, RM, LM                     73.00                59.00
# LM                             75.75                74.00
# LM, CAM                        71.50                69.75
# LM, CAM, CM                    74.00                69.00
# LM, CAM, LWB                   57.00                63.00
# LM, CAM, RM                    77.50                69.50
# LM, CAM, ST                    68.50                70.00
# LM, CF                         78.75                72.75
# LM, CF, CM                     70.00                71.00
# LM, CF, RM                     71.00                70.00
# LM, CM                         75.75                68.50
# LM, CM, CAM                    70.50                69.50
# LM, CM, LB                     74.25                64.75
# LM, CM, LWB                    68.00                63.00
# LM, LB                         80.50                62.50
# LM, LB, CAM                    72.00                64.00
# LM, LB, CM                     79.75                70.00
# LM, LB, LW                     75.00                59.00
# LM, LB, LWB                    78.00                72.00
# LM, LW                         74.25                72.00
# LM, LW, CAM                    71.75                68.75
# LM, LW, CF                     74.00                69.00
# LM, LW, CM                     74.00                72.00
# LM, LW, LB                     72.75                71.50
# LM, LW, RM                     71.50                67.00
# LM, LW, ST                     73.00                70.75
# LM, LWB                        82.00                72.00
# LM, LWB, LB                    69.00                60.00
# LM, LWB, LW                    77.00                67.00
# LM, RB                         75.00                69.00
# LM, RM                         74.00                72.00
# LM, RM, CAM                    71.00                71.00
# LM, RM, CF                     70.00                60.00
# LM, RM, CM                     72.75                69.25
# LM, RM, LB                     62.00                64.00
# LM, RM, LW                     78.00                76.00
# LM, RM, RB                     74.75                61.50
# LM, RM, ST                     70.00                74.25
# LM, RW                         77.00                65.25
# LM, RW, CAM                    69.00                62.00
# LM, RW, CF                     68.00                68.00
# LM, RW, LW                     82.00                64.00
# LM, RWB                        73.00                67.00
# LM, ST                         70.00                73.00
# LM, ST, CAM                    68.25                71.25
# LM, ST, LW                     64.00                69.00
# LM, ST, RM                     69.50                78.50
# LW                             75.25                71.00
# LW, CAM                        77.00                71.00
# LW, CAM, CM                    79.75                68.75
# LW, CAM, LM                    74.00                69.00
# LW, CAM, RM                    72.00                73.00
# LW, CAM, RW                    61.00                66.00
# LW, CF                         76.50                81.00
# LW, CF, RW                     73.00                78.00
# LW, CF, ST                     69.00                81.00
# LW, CM                         79.00                77.00
# LW, CM, CAM                    67.00                72.00
# LW, LB                         87.00                66.00
# LW, LM                         74.00                76.00
# LW, LM, CF                     72.00                76.00
# LW, LM, LB                     74.00                66.00
# LW, LM, RW                     79.00                80.50
# LW, LM, ST                     59.00                70.00
# LW, RM                         74.00                73.00
# LW, RM, LM                     74.00                63.00
# LW, RW                         77.25                70.50
# LW, RW, CAM                    70.75                74.25
# LW, RW, CM                     70.00                73.00
# LW, RW, LM                     74.25                73.75
# LW, RW, RM                     71.75                71.00
# LW, RW, ST                     70.00                74.00
# LW, ST                         71.25                72.75
# LW, ST, CAM                    64.00                71.00
# LW, ST, LM                     69.75                82.00
# LW, ST, RW                     66.00                71.00
# LWB                            71.00                50.00
# LWB, LB                        77.00                48.00
# LWB, LB, CB                    72.00                50.50
# LWB, LB, LM                    80.00                55.75
# LWB, LB, RB                    72.00                36.00
# LWB, LM                        71.00                55.00
# LWB, LM, LB                    82.00                58.50
# LWB, RM                        81.00                72.00
# LWB, RWB                       73.00                55.00
# RB                             76.00                54.00
# RB, CB                         72.25                49.75
# RB, CB, RM                     69.75                51.75
# RB, CB, RWB                    68.00                24.00
# RB, CB, ST                     68.00                60.00
# RB, CDM                        73.25                48.25
# RB, CDM, CM                    69.75                55.75
# RB, CM                         76.00                58.00
# RB, CM, CB                     64.00                46.00
# RB, CM, CDM                    91.00                66.00
# RB, LB                         75.00                50.00
# RB, LB, CB                     73.00                50.00
# RB, LB, CDM                    74.75                40.75
# RB, LB, RM                     80.00                67.00
# RB, LB, RWB                    74.25                39.25
# RB, LW, LB                     71.00                67.00
# RB, RM                         79.00                66.00
# RB, RM, CB                     76.00                67.00
# RB, RM, CM                     77.75                69.75
# RB, RM, LB                     73.00                70.00
# RB, RM, LM                     74.75                61.25
# RB, RM, RW                     68.00                61.00
# RB, RM, RWB                    75.00                57.50
# RB, RW                         79.50                62.00
# RB, RW, LW                     77.00                70.00
# RB, RWB                        76.00                55.00
# RB, RWB, LB                    69.00                42.00
# RB, RWB, RM                    77.00                61.00
# RM                             76.00                73.00
# RM, CAM                        76.75                72.75
# RM, CAM, CF                    72.00                66.00
# RM, CAM, CM                    76.25                68.50
# RM, CAM, LM                    76.00                76.50
# RM, CAM, RW                    77.00                74.00
# RM, CAM, ST                    64.25                71.75
# RM, CF                         72.00                67.75
# RM, CF, CAM                    66.00                65.00
# RM, CF, LM                     74.00                73.00
# RM, CF, RW                     75.00                72.50
# RM, CM                         81.00                71.00
# RM, CM, LM                     77.50                68.50
# RM, CM, RB                     79.00                60.00
# RM, CM, RW                     73.00                65.00
# RM, LM                         76.00                70.50
# RM, LM, CAM                    76.00                73.25
# RM, LM, CDM                    74.00                65.00
# RM, LM, CF                     79.50                74.00
# RM, LM, CM                     80.75                72.75
# RM, LM, LB                     77.00                60.00
# RM, LM, LW                     74.50                75.50
# RM, LM, RW                     74.00                72.00
# RM, LM, RWB                    73.00                64.75
# RM, LM, ST                     72.00                73.00
# RM, LW                         73.00                65.00
# RM, LW, RW                     67.00                68.00
# RM, RB                         78.25                66.25
# RM, RB, CM                     73.00                51.00
# RM, RB, LB                     75.00                48.00
# RM, RB, RWB                    74.00                70.00
# RM, RW                         76.50                72.00
# RM, RW, CAM                    78.00                68.00
# RM, RW, CM                     68.00                65.00
# RM, RW, LM                     73.00                74.50
# RM, RW, LW                     69.00                66.75
# RM, RW, ST                     75.75                81.25
# RM, RWB                        75.50                73.00
# RM, RWB, CAM                   75.00                64.00
# RM, RWB, LWB                   76.00                72.00
# RM, RWB, RB                    75.00                70.00
# RM, ST                         74.75                75.00
# RM, ST, CAM                    75.00                70.00
# RM, ST, LM                     73.25                72.00
# RM, ST, RW                     73.50                75.25
# RW                             74.50                72.00
# RW, CAM                        75.50                69.50
# RW, CAM, CM                    85.75                74.50
# RW, CAM, LW                    74.00                74.00
# RW, CAM, RM                    70.00                69.00
# RW, CAM, ST                    69.00                70.00
# RW, CF                         81.00                70.00
# RW, CF, LW                     73.75                75.75
# RW, CF, ST                     88.00                95.00
# RW, CM, RM                     72.00                74.00
# RW, LB                         70.00                70.00
# RW, LM, RM                     71.50                69.50
# RW, LW                         76.00                74.50
# RW, LW, CAM                    78.00                85.00
# RW, LW, CM                     65.00                59.00
# RW, LW, LM                     72.00                71.50
# RW, LW, RM                     72.25                70.00
# RW, LW, ST                     73.00                76.50
# RW, RM                         80.75                72.00
# RW, RM, CAM                    70.00                73.00
# RW, RM, CF                     74.00                68.00
# RW, RM, CM                     74.00                67.00
# RW, RM, LM                     66.00                70.00
# RW, RM, LW                     66.00                73.00
# RW, RM, RB                     73.50                68.00
# RW, RM, ST                     76.00                63.00
# RW, RWB                        71.00                58.00
# RW, ST                         74.00                76.00
# RW, ST, CF                     70.00                74.00
# RW, ST, LW                     68.00                72.00
# RW, ST, RM                     64.00                71.50
# RWB                            82.75                57.25
# RWB, RB                        73.00                56.00
# RWB, RB, LB                    69.00                20.00
# RWB, RB, LWB                   74.00                32.00
# RWB, RB, RM                    83.00                63.75
# RWB, RM                        74.00                56.00
# RWB, RM, RB                    78.00                49.50
# ST                             62.00                79.00
# ST, CAM                        65.50                77.00
# ST, CAM, CF                    71.75                77.75
# ST, CAM, CM                    68.00                70.00
# ST, CAM, LM                    67.50                76.50
# ST, CAM, LW                    74.50                83.75
# ST, CAM, RM                    64.25                71.25
# ST, CAM, RW                    59.00                71.25
# ST, CF                         61.00                78.00
# ST, CF, CAM                    57.75                75.50
# ST, CF, LW                     40.00                71.00
# ST, CF, RW                     64.00                75.00
# ST, CM, RB                     70.00                69.00
# ST, LM                         68.50                76.00
# ST, LM, CAM                    70.25                74.00
# ST, LM, LW                     68.00                78.00
# ST, LM, RB                     68.00                72.00
# ST, LM, RM                     68.00                72.25
# ST, LW                         69.00                78.00
# ST, LW, CAM                    71.25                76.25
# ST, LW, LM                     55.00                72.00
# ST, LW, RW                     63.75                73.75
# ST, RM                         69.50                77.00
# ST, RM, CAM                    72.00                76.00
# ST, RM, LM                     68.50                75.00
# ST, RM, LW                     54.00                74.00
# ST, RW                         72.00                78.00
# ST, RW, LM                     71.50                76.75
# ST, RW, LW                     68.00                77.00
# ST, RW, RM                     67.00                78.00
# ST, RWB                        64.00                68.00
#
#                   attacking_heading_accuracy  attacking_short_passing  \
# player_positions
# CAM                                    60.00                    79.00
# CAM, CDM                               58.75                    75.50
# CAM, CDM, CM                           64.75                    80.75
# CAM, CF                                66.00                    79.00
# CAM, CF, CM                            69.75                    71.50
# CAM, CF, RW                            49.75                    76.75
# CAM, CF, ST                            60.50                    78.75
# CAM, CM                                60.00                    78.00
# CAM, CM, CDM                           64.00                    76.25
# CAM, CM, CF                            58.00                    84.00
# CAM, CM, LM                            56.00                    78.00
# CAM, CM, LW                            65.00                    84.00
# CAM, CM, RM                            61.75                    78.75
# CAM, CM, RW                            59.50                    75.00
# CAM, CM, ST                            79.00                    72.00
# CAM, LM                                56.50                    76.00
# CAM, LM, CF                            46.00                    71.00
# CAM, LM, CM                            61.00                    76.50
# CAM, LM, LW                            44.00                    79.00
# CAM, LM, RM                            57.00                    77.00
# CAM, LM, RW                            55.00                    75.00
# CAM, LM, ST                            54.50                    81.00
# CAM, LW                                57.50                    79.25
# CAM, LW, CM                            58.50                    73.00
# CAM, LW, RW                            57.50                    72.25
# CAM, LW, ST                            59.25                    81.00
# CAM, RB                                50.00                    68.00
# CAM, RM                                61.00                    77.50
# CAM, RM, CF                            57.25                    77.50
# CAM, RM, CM                            62.00                    78.50
# CAM, RM, LM                            51.00                    75.00
# CAM, RM, RB                            43.00                    70.00
# CAM, RM, RW                            62.50                    78.00
# CAM, RM, ST                            66.50                    75.25
# CAM, RW                                66.25                    84.75
# CAM, RW, CF                            47.00                    72.00
# CAM, RW, CM                            50.00                    75.75
# CAM, RW, LW                            35.00                    72.00
# CAM, RW, RM                            52.00                    76.00
# CAM, ST                                70.00                    77.00
# CAM, ST, CDM                           56.00                    79.00
# CAM, ST, CF                            60.00                    77.00
# CAM, ST, LM                            56.00                    73.00
# CAM, ST, LW                            64.50                    75.00
# CAM, ST, RM                            60.50                    73.50
# CAM, ST, RW                            60.00                    73.75
# CB                                     78.00                    70.00
# CB, CDM                                76.00                    73.50
# CB, CDM, CM                            68.00                    66.50
# CB, CDM, LB                            75.00                    74.00
# CB, CDM, RB                            78.50                    70.00
# CB, CM, CDM                            71.00                    71.00
# CB, LB                                 74.00                    70.00
# CB, LB, CDM                            73.00                    71.00
# CB, LB, RB                             77.00                    72.00
# CB, LWB                                68.25                    70.25
# CB, RB                                 75.00                    71.00
# CB, RB, LB                             74.00                    68.00
# CB, RB, RM                             69.00                    72.00
# CB, RWB, RB                            66.00                    62.00
# CDM                                    72.00                    77.50
# CDM, CAM, CM                           60.25                    76.75
# CDM, CAM, LM                           44.00                    81.00
# CDM, CB                                74.50                    76.75
# CDM, CB, CM                            70.50                    76.50
# CDM, CB, LB                            75.00                    83.00
# CDM, CB, RB                            72.00                    71.00
# CDM, CM                                69.00                    78.00
# CDM, CM, CAM                           69.00                    76.00
# CDM, CM, CB                            74.25                    75.00
# CDM, CM, LB                            60.50                    71.25
# CDM, CM, LM                            70.00                    76.50
# CDM, CM, RB                            61.25                    79.25
# CDM, CM, RM                            67.50                    73.00
# CDM, LB                                59.50                    72.50
# CDM, LB, CM                            63.75                    73.00
# CDM, RB                                61.00                    71.00
# CDM, RB, RM                            73.00                    72.00
# CDM, RM                                46.00                    74.00
# CDM, RWB                               65.00                    77.00
# CF                                     64.00                    82.00
# CF, CAM                                59.00                    76.00
# CF, CAM, CM                            50.00                    88.00
# CF, CAM, LM                            72.25                    67.25
# CF, CAM, ST                            61.00                    76.00
# CF, CM                                 76.00                    80.00
# CF, CM, LW                             50.00                    80.00
# CF, LM                                 65.00                    83.00
# CF, LM, LW                             47.00                    75.00
# CF, LW                                 64.75                    72.75
# CF, LW, CAM                            60.50                    77.00
# CF, LW, RW                             60.00                    75.00
# CF, LW, ST                             59.00                    87.00
# CF, RM, LM                             50.00                    77.00
# CF, RW                                 53.00                    82.00
# CF, RW, LW                             40.00                    78.00
# CF, RW, RM                             75.00                    75.00
# CF, RW, ST                             65.00                    72.00
# CF, ST                                 69.00                    82.00
# CF, ST, CAM                            71.75                    79.75
# CF, ST, LW                             84.00                    85.00
# CF, ST, RM                             64.00                    82.25
# CM                                     64.00                    79.75
# CM, CAM                                63.00                    80.00
# CM, CAM, CDM                           70.00                    81.00
# CM, CAM, CF                            57.00                    83.00
# CM, CAM, LM                            64.00                    79.00
# CM, CAM, RM                            55.75                    78.50
# CM, CAM, RW                            51.00                    79.00
# CM, CAM, ST                            72.00                    73.00
# CM, CB                                 78.00                    79.00
# CM, CB, CAM                            82.00                    76.00
# CM, CDM                                67.00                    80.00
# CM, CDM, CAM                           65.75                    79.75
# CM, CDM, CB                            68.50                    78.00
# CM, CDM, CF                            63.00                    74.00
# CM, CDM, LB                            70.00                    77.00
# CM, CDM, LM                            67.00                    83.00
# CM, CDM, LW                            47.50                    74.50
# CM, CDM, RB                            64.25                    77.50
# CM, CDM, RM                            59.75                    82.50
# CM, CDM, RWB                           65.00                    79.00
# CM, CF                                 59.00                    73.00
# CM, CF, CAM                            54.00                    74.00
# CM, LB                                 66.00                    77.00
# CM, LM                                 59.50                    78.75
# CM, LM, CAM                            55.50                    79.00
# CM, LM, CDM                            52.50                    80.75
# CM, LM, LB                             58.25                    76.00
# CM, LM, RB                             56.00                    72.00
# CM, LM, RM                             65.00                    84.25
# CM, LW                                 66.50                    81.50
# CM, LW, RW                             60.00                    81.50
# CM, LWB                                67.00                    78.50
# CM, LWB, LM                            68.00                    74.00
# CM, RB                                 64.75                    77.25
# CM, RB, RM                             68.00                    81.00
# CM, RM                                 57.75                    78.75
# CM, RM, CAM                            58.50                    77.25
# CM, RM, CDM                            59.50                    76.75
# CM, RM, RB                             51.00                    74.00
# CM, RW                                 61.00                    72.00
# CM, RW, CAM                            45.25                    78.50
# CM, RWB, RM                            45.00                    71.00
# CM, ST                                 92.00                    80.00
# GK                                     17.00                    35.00
# LB                                     70.00                    76.25
# LB, CAM, LM                            52.00                    68.00
# LB, CB                                 73.50                    77.00
# LB, CB, CDM                            75.00                    67.00
# LB, CB, LM                             61.00                    72.00
# LB, CB, LWB                            68.50                    70.50
# LB, CDM                                68.00                    74.50
# LB, CM                                 63.25                    77.50
# LB, CM, LM                             54.00                    72.00
# LB, LM                                 68.00                    76.00
# LB, LM, CAM                            60.00                    75.00
# LB, LM, LWB                            68.50                    75.00
# LB, LM, RM                             64.00                    65.00
# LB, LW                                 62.00                    67.50
# LB, LWB                                68.00                    74.00
# LB, LWB, CDM                           60.00                    71.00
# LB, LWB, LM                            69.50                    75.00
# LB, LWB, RB                            67.00                    71.00
# LB, RB                                 64.75                    73.50
# LB, RB, CB                             64.50                    68.00
# LB, RB, RM                             62.00                    69.00
# LB, RM                                 54.75                    72.50
# LB, RM, LM                             51.00                    67.00
# LM                                     61.75                    75.00
# LM, CAM                                56.75                    75.75
# LM, CAM, CM                            40.00                    80.00
# LM, CAM, LWB                           40.00                    71.00
# LM, CAM, RM                            58.00                    77.50
# LM, CAM, ST                            52.50                    76.00
# LM, CF                                 45.25                    75.00
# LM, CF, CM                             53.00                    76.00
# LM, CF, RM                             67.00                    70.00
# LM, CM                                 61.00                    76.50
# LM, CM, CAM                            44.00                    72.50
# LM, CM, LB                             62.25                    73.50
# LM, CM, LWB                            51.00                    70.00
# LM, LB                                 65.50                    75.00
# LM, LB, CAM                            59.00                    72.00
# LM, LB, CM                             50.50                    80.25
# LM, LB, LW                             58.00                    66.00
# LM, LB, LWB                            64.00                    73.00
# LM, LW                                 56.00                    74.00
# LM, LW, CAM                            51.75                    74.00
# LM, LW, CF                             33.00                    73.00
# LM, LW, CM                             42.00                    78.00
# LM, LW, LB                             58.75                    72.00
# LM, LW, RM                             53.00                    73.50
# LM, LW, ST                             66.25                    72.75
# LM, LWB                                48.25                    74.50
# LM, LWB, LB                            47.00                    66.00
# LM, LWB, LW                            49.00                    77.00
# LM, RB                                 60.00                    76.00
# LM, RM                                 58.00                    73.00
# LM, RM, CAM                            57.00                    72.75
# LM, RM, CF                             60.00                    65.00
# LM, RM, CM                             60.25                    73.75
# LM, RM, LB                             51.00                    64.00
# LM, RM, LW                             52.00                    76.00
# LM, RM, RB                             68.50                    73.50
# LM, RM, ST                             65.75                    72.25
# LM, RW                                 42.75                    77.00
# LM, RW, CAM                            64.00                    68.00
# LM, RW, CF                             51.00                    72.00
# LM, RW, LW                             50.00                    83.00
# LM, RWB                                63.00                    73.00
# LM, ST                                 65.75                    71.75
# LM, ST, CAM                            64.50                    73.00
# LM, ST, LW                             58.00                    71.00
# LM, ST, RM                             75.25                    76.75
# LW                                     57.00                    75.25
# LW, CAM                                62.00                    75.00
# LW, CAM, CM                            54.50                    81.00
# LW, CAM, LM                            45.00                    72.00
# LW, CAM, RM                            67.00                    76.00
# LW, CAM, RW                            33.00                    76.00
# LW, CF                                 68.00                    84.50
# LW, CF, RW                             52.00                    74.00
# LW, CF, ST                             54.00                    78.00
# LW, CM                                 48.00                    84.00
# LW, CM, CAM                            47.00                    78.00
# LW, LB                                 63.00                    78.00
# LW, LM                                 64.00                    74.00
# LW, LM, CF                             49.00                    71.00
# LW, LM, LB                             67.00                    68.00
# LW, LM, RW                             41.75                    78.25
# LW, LM, ST                             52.00                    70.00
# LW, RM                                 74.00                    77.00
# LW, RM, LM                             45.00                    73.00
# LW, RW                                 57.00                    76.00
# LW, RW, CAM                            61.50                    77.50
# LW, RW, CM                             59.00                    72.00
# LW, RW, LM                             62.50                    73.25
# LW, RW, RM                             46.50                    69.00
# LW, RW, ST                             62.25                    69.50
# LW, ST                                 62.75                    72.00
# LW, ST, CAM                            68.00                    70.00
# LW, ST, LM                             70.25                    77.25
# LW, ST, RW                             55.50                    68.50
# LWB                                    56.50                    69.00
# LWB, LB                                62.50                    74.50
# LWB, LB, CB                            72.00                    70.00
# LWB, LB, LM                            69.00                    74.00
# LWB, LB, RB                            66.00                    68.00
# LWB, LM                                66.00                    70.00
# LWB, LM, LB                            54.75                    77.75
# LWB, RM                                39.00                    75.00
# LWB, RWB                               63.00                    70.00
# RB                                     68.00                    74.00
# RB, CB                                 72.25                    72.25
# RB, CB, RM                             59.75                    70.50
# RB, CB, RWB                            63.00                    64.00
# RB, CB, ST                             68.00                    63.00
# RB, CDM                                67.25                    72.00
# RB, CDM, CM                            71.50                    76.75
# RB, CM                                 62.00                    78.00
# RB, CM, CB                             70.00                    77.00
# RB, CM, CDM                            74.00                    87.00
# RB, LB                                 68.00                    74.75
# RB, LB, CB                             60.00                    68.00
# RB, LB, CDM                            66.00                    70.00
# RB, LB, RM                             68.00                    75.00
# RB, LB, RWB                            63.75                    70.50
# RB, LW, LB                             62.00                    72.00
# RB, RM                                 71.00                    77.00
# RB, RM, CB                             69.50                    74.00
# RB, RM, CM                             69.75                    78.00
# RB, RM, LB                             57.00                    72.00
# RB, RM, LM                             66.75                    74.50
# RB, RM, RW                             70.00                    65.00
# RB, RM, RWB                            63.25                    69.00
# RB, RW                                 57.50                    76.00
# RB, RW, LW                             72.00                    77.00
# RB, RWB                                68.00                    73.00
# RB, RWB, LB                            56.25                    65.50
# RB, RWB, RM                            64.50                    75.00
# RM                                     58.25                    74.00
# RM, CAM                                53.75                    76.75
# RM, CAM, CF                            63.00                    70.00
# RM, CAM, CM                            60.50                    78.00
# RM, CAM, LM                            64.50                    77.50
# RM, CAM, RW                            53.00                    81.00
# RM, CAM, ST                            41.50                    66.75
# RM, CF                                 61.75                    68.00
# RM, CF, CAM                            45.00                    74.00
# RM, CF, LM                             43.00                    74.00
# RM, CF, RW                             58.25                    75.00
# RM, CM                                 56.00                    74.00
# RM, CM, LM                             61.00                    71.50
# RM, CM, RB                             56.00                    78.00
# RM, CM, RW                             67.00                    78.00
# RM, LM                                 58.00                    73.50
# RM, LM, CAM                            56.25                    73.50
# RM, LM, CDM                            46.00                    72.00
# RM, LM, CF                             54.75                    80.25
# RM, LM, CM                             62.75                    81.50
# RM, LM, LB                             52.00                    74.00
# RM, LM, LW                             60.50                    75.50
# RM, LM, RW                             54.00                    70.00
# RM, LM, RWB                            57.75                    66.25
# RM, LM, ST                             68.00                    76.00
# RM, LW                                 50.00                    72.00
# RM, LW, RW                             43.00                    65.00
# RM, RB                                 64.75                    77.00
# RM, RB, CM                             65.00                    74.00
# RM, RB, LB                             76.00                    70.00
# RM, RB, RWB                            71.00                    73.00
# RM, RW                                 63.00                    74.00
# RM, RW, CAM                            60.00                    75.00
# RM, RW, CM                             54.00                    68.00
# RM, RW, LM                             55.00                    74.00
# RM, RW, LW                             49.75                    68.75
# RM, RW, ST                             69.00                    75.75
# RM, RWB                                64.25                    75.25
# RM, RWB, CAM                           60.00                    71.00
# RM, RWB, LWB                           44.00                    75.00
# RM, RWB, RB                            45.00                    69.00
# RM, ST                                 71.00                    73.75
# ...
# CAM, RM, RW                         13.00
# CAM, RM, ST                          8.00
# CAM, RW                             12.00
# CAM, RW, CF                          5.00
# CAM, RW, CM                         10.75
# CAM, RW, LW                          7.00
# CAM, RW, RM                          6.00
# CAM, ST                             15.00
# CAM, ST, CDM                         9.00
# CAM, ST, CF                         12.00
# CAM, ST, LM                         15.00
# CAM, ST, LW                         12.00
# CAM, ST, RM                         14.00
# CAM, ST, RW                         13.50
# CB                                  14.00
# CB, CDM                             14.00
# CB, CDM, CM                         10.75
# CB, CDM, LB                         10.00
# CB, CDM, RB                         14.00
# CB, CM, CDM                          7.00
# CB, LB                              13.00
# CB, LB, CDM                          7.00
# CB, LB, RB                          15.00
# CB, LWB                             10.75
# CB, RB                              12.00
# CB, RB, LB                          12.00
# CB, RB, RM                           9.00
# CB, RWB, RB                          9.00
# CDM                                 13.50
# CDM, CAM, CM                        14.00
# CDM, CAM, LM                         8.00
# CDM, CB                             12.00
# CDM, CB, CM                         16.00
# CDM, CB, LB                         14.00
# CDM, CB, RB                         18.00
# CDM, CM                             14.00
# CDM, CM, CAM                        11.00
# CDM, CM, CB                         13.75
# CDM, CM, LB                         14.75
# CDM, CM, LM                         14.50
# CDM, CM, RB                         11.00
# CDM, CM, RM                         12.00
# CDM, LB                             12.25
# CDM, LB, CM                         12.75
# CDM, RB                              8.00
# CDM, RB, RM                          8.00
# CDM, RM                             10.00
# CDM, RWB                             8.00
# CF                                  11.00
# CF, CAM                              9.75
# CF, CAM, CM                          6.00
# CF, CAM, LM                         12.00
# CF, CAM, ST                         11.50
# CF, CM                              16.00
# CF, CM, LW                           7.00
# CF, LM                               6.00
# CF, LM, LW                          11.00
# CF, LW                              10.50
# CF, LW, CAM                         11.50
# CF, LW, RW                          15.00
# CF, LW, ST                           9.00
# CF, RM, LM                           7.00
# CF, RW                              13.00
# CF, RW, LW                          11.00
# CF, RW, RM                          14.00
# CF, RW, ST                          13.00
# CF, ST                              12.00
# CF, ST, CAM                         10.00
# CF, ST, LW                          13.00
# CF, ST, RM                          12.00
# CM                                  14.00
# CM, CAM                             13.00
# CM, CAM, CDM                        14.00
# CM, CAM, CF                         15.00
# CM, CAM, LM                         15.00
# CM, CAM, RM                         15.25
# CM, CAM, RW                         14.75
# CM, CAM, ST                          9.00
# CM, CB                              14.00
# CM, CB, CAM                          9.00
# CM, CDM                             13.00
# CM, CDM, CAM                        14.00
# CM, CDM, CB                         12.25
# CM, CDM, CF                         14.00
# CM, CDM, LB                         15.00
# CM, CDM, LM                         13.00
# CM, CDM, LW                          6.75
# CM, CDM, RB                         13.50
# CM, CDM, RM                         10.50
# CM, CDM, RWB                        10.00
# CM, CF                               6.00
# CM, CF, CAM                         10.00
# CM, LB                              11.00
# CM, LM                              14.25
# CM, LM, CAM                         12.50
# CM, LM, CDM                         15.00
# CM, LM, LB                          10.25
# CM, LM, RB                          10.00
# CM, LM, RM                          12.00
# CM, LW                              12.00
# CM, LW, RW                          13.00
# CM, LWB                             14.00
# CM, LWB, LM                         14.00
# CM, RB                              11.50
# CM, RB, RM                          13.00
# CM, RM                              14.75
# CM, RM, CAM                          9.50
# CM, RM, CDM                         14.25
# CM, RM, RB                           6.00
# CM, RW                              12.00
# CM, RW, CAM                         11.00
# CM, RWB, RM                         11.00
# CM, ST                              15.00
# GK                                  77.00
# LB                                  13.00
# LB, CAM, LM                          9.00
# LB, CB                              13.00
# LB, CB, CDM                         13.00
# LB, CB, LM                          15.00
# LB, CB, LWB                         10.50
# LB, CDM                             11.50
# LB, CM                              11.75
# LB, CM, LM                          12.00
# LB, LM                              13.00
# LB, LM, CAM                          8.00
# LB, LM, LWB                         15.50
# LB, LM, RM                           9.00
# LB, LW                              14.00
# LB, LWB                             11.00
# LB, LWB, CDM                         9.00
# LB, LWB, LM                         12.50
# LB, LWB, RB                         14.00
# LB, RB                              12.75
# LB, RB, CB                          14.75
# LB, RB, RM                          15.00
# LB, RM                              14.00
# LB, RM, LM                           5.00
# LM                                  13.00
# LM, CAM                             13.00
# LM, CAM, CM                         15.00
# LM, CAM, LWB                        14.00
# LM, CAM, RM                         11.50
# LM, CAM, ST                          9.50
# LM, CF                               8.00
# LM, CF, CM                          12.00
# LM, CF, RM                          11.50
# LM, CM                              15.00
# LM, CM, CAM                         15.00
# LM, CM, LB                           9.75
# LM, CM, LWB                         14.00
# LM, LB                              15.00
# LM, LB, CAM                          7.00
# LM, LB, CM                          10.75
# LM, LB, LW                          15.00
# LM, LB, LWB                          7.00
# LM, LW                              13.75
# LM, LW, CAM                         14.00
# LM, LW, CF                           6.00
# LM, LW, CM                           8.00
# LM, LW, LB                          11.00
# LM, LW, RM                          15.00
# LM, LW, ST                          13.75
# LM, LWB                             12.75
# LM, LWB, LB                         12.00
# LM, LWB, LW                          6.00
# LM, RB                              12.00
# LM, RM                              12.00
# LM, RM, CAM                         13.00
# LM, RM, CF                           5.00
# LM, RM, CM                          11.75
# LM, RM, LB                           5.00
# LM, RM, LW                          11.00
# LM, RM, RB                          10.00
# LM, RM, ST                          14.00
# LM, RW                              14.25
# LM, RW, CAM                         15.00
# LM, RW, CF                           7.00
# LM, RW, LW                          12.00
# LM, RWB                              6.00
# LM, ST                              12.50
# LM, ST, CAM                         14.50
# LM, ST, LW                          11.00
# LM, ST, RM                          14.25
# LW                                  11.25
# LW, CAM                             15.00
# LW, CAM, CM                          9.75
# LW, CAM, LM                         10.00
# LW, CAM, RM                         12.00
# LW, CAM, RW                         14.00
# LW, CF                              10.50
# LW, CF, RW                          14.00
# LW, CF, ST                           7.00
# LW, CM                              14.00
# LW, CM, CAM                          6.00
# LW, LB                              13.00
# LW, LM                              13.00
# LW, LM, CF                          13.00
# LW, LM, LB                          15.00
# LW, LM, RW                          13.00
# LW, LM, ST                           9.00
# LW, RM                              12.00
# LW, RM, LM                           6.00
# LW, RW                              13.00
# LW, RW, CAM                         12.25
# LW, RW, CM                          14.00
# LW, RW, LM                           9.00
# LW, RW, RM                          10.50
# LW, RW, ST                          12.00
# LW, ST                              13.50
# LW, ST, CAM                          9.00
# LW, ST, LM                          12.75
# LW, ST, RW                          13.50
# LWB                                  7.50
# LWB, LB                             11.50
# LWB, LB, CB                         11.50
# LWB, LB, LM                          8.25
# LWB, LB, RB                         10.00
# LWB, LM                              8.00
# LWB, LM, LB                          8.50
# LWB, RM                             14.00
# LWB, RWB                             8.00
# RB                                  13.00
# RB, CB                              13.25
# RB, CB, RM                           9.25
# RB, CB, RWB                         13.00
# RB, CB, ST                          12.00
# RB, CDM                             12.25
# RB, CDM, CM                         13.50
# RB, CM                              11.00
# RB, CM, CB                           8.00
# RB, CM, CDM                         15.00
# RB, LB                              13.75
# RB, LB, CB                           8.00
# RB, LB, CDM                          8.75
# RB, LB, RM                          12.00
# RB, LB, RWB                          9.25
# RB, LW, LB                          13.00
# RB, RM                              13.25
# RB, RM, CB                          11.00
# RB, RM, CM                          15.25
# RB, RM, LB                           9.00
# RB, RM, LM                          13.75
# RB, RM, RW                           5.00
# RB, RM, RWB                         11.50
# RB, RW                              12.00
# RB, RW, LW                          11.00
# RB, RWB                             13.00
# RB, RWB, LB                         13.50
# RB, RWB, RM                         13.50
# RM                                  13.00
# RM, CAM                             12.00
# RM, CAM, CF                          8.00
# RM, CAM, CM                         11.00
# RM, CAM, LM                         15.00
# RM, CAM, RW                          5.00
# RM, CAM, ST                          9.00
# RM, CF                              12.75
# RM, CF, CAM                         14.00
# RM, CF, LM                          12.00
# RM, CF, RW                           7.00
# RM, CM                              13.00
# RM, CM, LM                          11.50
# RM, CM, RB                           5.00
# RM, CM, RW                          15.00
# RM, LM                              14.00
# RM, LM, CAM                         11.75
# RM, LM, CDM                          7.00
# RM, LM, CF                           7.75
# RM, LM, CM                          10.50
# RM, LM, LB                          13.00
# RM, LM, LW                           9.00
# RM, LM, RW                          15.00
# RM, LM, RWB                         15.00
# RM, LM, ST                          11.00
# RM, LW                              15.00
# RM, LW, RW                           5.00
# RM, RB                              14.00
# RM, RB, CM                          12.00
# RM, RB, LB                           9.00
# RM, RB, RWB                         10.00
# RM, RW                              12.50
# RM, RW, CAM                         10.00
# RM, RW, CM                          15.00
# RM, RW, LM                          10.00
# RM, RW, LW                          12.75
# RM, RW, ST                          12.00
# RM, RWB                             14.25
# RM, RWB, CAM                        13.00
# RM, RWB, LWB                        11.00
# RM, RWB, RB                         12.00
# RM, ST                              11.75
# RM, ST, CAM                         15.00
# RM, ST, LM                          13.75
# RM, ST, RW                          11.75
# RW                                  10.50
# RW, CAM                             13.50
# RW, CAM, CM                         11.00
# RW, CAM, LW                         14.00
# RW, CAM, RM                         13.00
# RW, CAM, ST                          6.00
# RW, CF                               8.75
# RW, CF, LW                          14.75
# RW, CF, ST                          14.00
# RW, CM, RM                          15.00
# RW, LB                              15.00
# RW, LM, RM                           7.75
# RW, LW                              13.00
# RW, LW, CAM                         13.00
# RW, LW, CM                           8.00
# RW, LW, LM                          13.25
# RW, LW, RM                           7.75
# RW, LW, ST                          10.75
# RW, RM                              11.75
# RW, RM, CAM                         10.00
# RW, RM, CF                           9.00
# RW, RM, CM                          16.00
# RW, RM, LM                          10.00
# RW, RM, LW                          10.00
# RW, RM, RB                          13.75
# RW, RM, ST                          10.00
# RW, RWB                             12.00
# RW, ST                              11.00
# RW, ST, CF                          16.00
# RW, ST, LW                          11.00
# RW, ST, RM                          13.50
# RWB                                  9.75
# RWB, RB                             11.00
# RWB, RB, LB                         11.00
# RWB, RB, LWB                        12.00
# RWB, RB, RM                         10.75
# RWB, RM                             13.00
# RWB, RM, RB                         10.50
# ST                                  13.00
# ST, CAM                             13.00
# ST, CAM, CF                         11.50
# ST, CAM, CM                         14.00
# ST, CAM, LM                         10.50
# ST, CAM, LW                          8.50
# ST, CAM, RM                          9.75
# ST, CAM, RW                         12.75
# ST, CF                              14.75
# ST, CF, CAM                         10.00
# ST, CF, LW                          12.00
# ST, CF, RW                           9.00
# ST, CM, RB                          16.00
# ST, LM                              14.00
# ST, LM, CAM                          9.75
# ST, LM, LW                          12.00
# ST, LM, RB                          13.00
# ST, LM, RM                          10.25
# ST, LW                              12.00
# ST, LW, CAM                         11.50
# ST, LW, LM                           9.00
# ST, LW, RW                          13.75
# ST, RM                              11.00
# ST, RM, CAM                         12.00
# ST, RM, LM                          12.00
# ST, RM, LW                          15.00
# ST, RW                              12.00
# ST, RW, LM                          13.75
# ST, RW, LW                          12.00
# ST, RW, RM                          11.00
# ST, RWB                              1.00

# %%
len(df_n_playerp)
# Out:
# 395

# %%
# Podríamos decir que obtuvimos 395 grupos

# %%
df_n_playerp.columns
# Out:
# Index(['attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning'],
#       dtype='object')

# %%
# Planteamos un método de correlación que nos diga si están correlacionadas las variables
correlacion=df_n_playerp.corr()

# %%
# Seleccionamos aquellas variables que estén menos correlacionadas, de esta forma, en vez de formar una recta juntas,
# los datos representados por estas variables se encuentran lo más disperso posible
interesting_skill = correlacion['attacking_short_passing']
interesting_skill= interesting_skill.abs().sort_values(ascending=True)
interesting_skill[1:6]
# Out:
# power_strength                0.021853
# defending_sliding_tackle      0.039256
# defending_standing_tackle     0.087068
# movement_sprint_speed         0.091967
# attacking_heading_accuracy    0.097543
# Name: attacking_short_passing, dtype: float64

# %%
# Graficamos...

data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores

#Elejimos dos variables, para esto elejimos dos números entre 0 y  de n_skills-1

skill_1='defending_sliding_tackle'
skill_2='attacking_short_passing'

#skill_1=skills_ratings[4]
#skill_2=skills_ratings[21]



graf1 = go.Scatter(x=df_skills[skill_1], y=df_skills[skill_2],
                           mode='markers',
                        text=df_n.loc[:,'player_positions'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Top players',
                      text=df_n.loc[bool_crack,'player_positions'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf1,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>                            <div id="1966c473-a167-4253-9317-b8c83dcbbb27" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1966c473-a167-4253-9317-b8c83dcbbb27")) {                    Plotly.newPlot(                        "1966c473-a167-4253-9317-b8c83dcbbb27",                        [{"marker": {"size": 5}, "mode": "markers", "text": ["RW, CF, ST", "ST, LW", "LW, CAM", "GK", "LW, CF", "CAM, CM", "GK", "CB", "CM", "RW, ST", "ST, RW", "CB", "ST", "GK", "GK", "CDM, CM", "CB", "ST", "CB", "ST", "ST", "CDM, CM", "CF, ST, LW", "CAM, RW", "CM, CDM", "GK", "RW, LW", "CAM, CM", "GK", "CB", "GK", "GK", "GK", "CAM, CM", "ST", "CB", "CM", "CAM, LM, ST", "ST, LM", "LW, LM", "CB, LB", "RW, CAM, CM", "CDM", "CF, LM", "CDM", "CB", "CF, ST", "CB", "CF, ST", "CB", "CB", "LB", "CM, CAM, CDM", "GK", "CF, LW, ST", "LW", "CB, CDM", "CB", "CM, CDM", "CB", "GK", "RB, CM, CDM", "CAM, CM, LW", "CF, ST, CAM", "CM, CDM", "CM, CDM", "RW, LW", "CB", "LW, CM", "CM", "CAM, RM, RW", "ST", "ST", "CB", "GK", "CM, CDM", "CB", "CB", "CM, CAM", "CDM, CM", "CM, LM, RM", "CDM", "LB", "CB", "CB", "CAM, CM", "GK", "GK", "GK", "ST", "CB", "GK", "LB, CB", "ST", "RB", "CAM, RW", "ST", "CAM, CF, ST", "ST", "CDM, CM", "RW, LW, ST", "LB", "CDM, CM", "LB, LM", "ST, RW", "RM, LM, CM", "CAM, CM, RM", "CM", "RM, LM", "CAM, RM", "RW, LW", "GK", "RB", "CAM, CM", "CB, LB", "CM", "CF, LW, CAM", "CM, CAM, CDM", "CAM, LM, RM", "LM, RM, LW", "RM, LM, LW", "CAM", "GK", "CAM, CM, CF", "LB", "GK", "CB", "LM", "CB", "CM", "GK", "GK", "CM", "CB", "CDM", "CAM, RW", "CDM, CB", "GK", "ST", "CM, CDM", "LM", "ST, LW", "CM, CDM", "CB", "RB, CB", "RM, RW", "CM, CDM", "CM, CAM, CDM", "RB", "CAM, CM, CF", "LM, RW, LW", "RM, CM", "CAM, LW, ST", "CF, ST", "RW, RM", "RM, RW", "CB", "CM, CDM, CAM", "CB", "CM, CAM, CF", "RB", "ST", "ST", "LW, ST, LM", "CAM, RW", "CB", "CM, CDM", "GK", "LM, ST", "RM, RW, ST", "CB", "ST, LM", "CB", "CM, CDM", "LB", "ST", "LM, CAM, RM", "CB", "LW, RW", "LB", "CAM, CM, LW", "GK", "LM", "ST", "GK", "CF, LM, LW", "ST", "ST", "ST", "CDM, CM", "RM, CAM", "CB", "CAM, CM", "GK", "CB", "CAM, CM, RM", "GK", "CF, RM, LM", "RW, RM", "CM, CDM", "GK", "GK", "GK", "CB", "CB", "ST", "GK", "ST", "CB", "RW, LW, CAM", "CB", "GK", "CAM, CM", "CDM, CM, CAM", "ST", "CM, CDM", "CB", "CF, ST, CAM", "CDM, CM", "CAM", "CM, CAM", "CDM, CM", "CDM, CB, LB", "GK", "CB", "RM, RW", "CDM", "CM, CAM, CDM", "ST", "CM, CDM", "ST", "CB", "CDM, CM", "ST, CAM, LW", "ST, CF", "CB", "RW, CAM", "LW, LM, RW", "LW, RW", "ST", "CM", "ST", "GK", "CM, CDM", "CDM, CM", "CM", "CB", "RW, CAM, LW", "GK", "RB", "GK", "GK", "CB", "RM, ST", "ST, RW", "RW, LW", "RM, RW", "GK", "CM, CDM, RM", "CM", "CB", "RW, CF", "CB", "CB", "GK", "RB, RM", "LB", "GK", "GK", "CAM, LW", "CF, CAM, CM", "CDM, CM", "GK", "ST", "RB, RM, CM", "LWB, LM, LB", "ST, RW, LW", "CB, LB, RB", "CB", "LB", "CB", "RM, LM, CF", "CAM, LM", "LM, LWB", "RM, ST", "LM, RM", "GK", "CDM", "ST", "RM, RB", "CM, CDM, LM", "CM", "CDM, CM", "GK", "GK", "CAM, RM", "ST", "CB", "RW, LW", "CB", "ST", "LW, LM", "CAM", "LB", "ST", "RM, CAM", "CAM, LM", "ST", "CM, LW", "RW, LW", "ST", "LW", "CM, CDM", "RW, RM", "RWB, RM", "CB", "ST", "RB, RM", "RW", "CAM, RW", "LW, RW", "ST", "ST", "ST, LM", "GK", "CB, CDM", "CDM, CM, CAM", "CB", "CAM, RM", "ST", "CM", "CM, CDM", "CB, RB", "GK", "CAM, CM", "CB", "CM, LM, CDM", "CAM, CM, LM", "CM, CDM", "LB", "LW, RW, CAM", "CM, LM", "GK", "CM, CDM", "CAM, CM, RW", "CM, CDM", "CAM, CM", "LB", "ST", "CDM, CM", "CDM, CM", "GK", "CB", "ST, LW", "ST", "LM", "CB, CDM", "LM, LB, CM", "CAM, CM", "CDM, CM", "CB", "CDM, CM", "CAM, LW", "RM, RB", "GK", "GK", "CDM, CM", "ST, CF", "ST", "RM, LM", "CB", "CM, LB", "ST", "ST", "CM, CAM, CDM", "CM, CDM", "GK", "CB", "CB", "CM, CAM, CDM", "CB", "CM, CDM, LM", "RB", "ST ...

# %%
# En el gráfico anterior se puede ver el agrupamiento por "player positions". Si bien se diferencian dos grandes grupos,
# se puede ver que se diferencian grupos pequeños también.

# %% [markdown]
# Graficamos diferenciando los mejores jugadores y alguna característica de interés (Elegir)
#
# Se puede ubicar un jugador con la siguiente linea de comando, por ejemplo, Leo Messi:

# %%
#Gráfico 2

#Elegimos un jugador
recherche_joueur=df_n["short_name"]=='L. Messi' 
recherche_joueur2=df_n["short_name"]=='Cristiano Ronaldo' # acá podemos elegir otro 


bool_crack=df_n["overall"] > 85
bool_elecc=df_n["club"]=='FC Barcelona' 
#bool_elecc=df_n["Position"]=='GK' #arqueros
bool_no_crack=df_n["overall"]<86
bool_machinegun=df_n["short_name"]=='MachineGun'

#Elegir dos números entre 0 y  de n_skills-1
skill_1='defending_sliding_tackle'  #6
skill_2='attacking_short_passing'  #25


palette=['navy','red','#A2D5F2','orange','green','pink']  

data=[]

n_crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Crack',
                      text=df_n.loc[bool_crack,'player_positions'],
                      textfont=dict(family='sans serif',size=15,color='black'),
                      opacity=0.9,marker=dict(color=palette[2],size=7),mode='markers+text')#mode='markers+text'

n_no_crack =go.Scatter(x=df_skills.loc[bool_no_crack,skill_1], y=df_skills.loc[bool_no_crack,skill_2],name='Average player',
                         text=df_n.loc[bool_no_crack,'short_name'],
                         opacity=0.6,marker=dict(color=palette[1],size=3),mode='markers')
n_elecc=go.Scatter(x=df_skills.loc[bool_elecc,skill_1], y=df_skills.loc[bool_elecc,skill_2],name='Elección',
                         text=df_n.loc[bool_elecc,'short_name'],
                         opacity=0.6,marker=dict(color=palette[0],size=5),mode='markers')

n_machinegun =go.Scatter(x=df_skills.loc[bool_machinegun,skill_1], y=df_skills.loc[bool_machinegun,skill_2],name='Perfect player',
                           textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=0.6,marker=dict(color=palette[3],size=30),mode='markers+text')


joueur_recherche =go.Scatter(x=df_skills.loc[recherche_joueur,skill_1], y=df_skills.loc[recherche_joueur,skill_2],name='Messi',
                           text=df_n.loc[recherche_joueur,'player_positions'],
                            textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=1,marker=dict(color=palette[4],size=40),mode='markers+text')

joueur_recherche2 =go.Scatter(x=df_skills.loc[recherche_joueur2,skill_1], y=df_skills.loc[recherche_joueur2,skill_2],name='Ronaldo',
                           text=df_n.loc[recherche_joueur2,'player_positions'],
                            textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=1,marker=dict(color=palette[0],size=40),mode='markers+text')

data=[n_no_crack,n_elecc
      ,n_crack,n_machinegun,joueur_recherche,joueur_recherche2]

layout = go.Layout(title="Fifa Players",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>                            <div id="d3187d13-1909-4e43-9213-9e56c9a7684f" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3187d13-1909-4e43-9213-9e56c9a7684f")) {                    Plotly.newPlot(                        "d3187d13-1909-4e43-9213-9e56c9a7684f",                        [{"marker": {"color": "red", "size": 3}, "mode": "markers", "name": "Average player", "opacity": 0.6, "text": ["M. de Ligt", "G. Donnarumma", "F. de Jong", "R. Varane", "N. S\u00fcle", "S. Milinkovi\u0107-Savi\u0107", "Rodri", "Sa\u00fal", "Fabinho", "A. Robertson", "J. Gim\u00e9nez", "C. Lenglet", "Bruno Fernandes", "A. Lopes", "P. Gul\u00e1csi", "R. B\u00fcrki", "R. Lukaku", "K. Manolas", "Neto", "D. Alaba", "M. Icardi", "Carvajal", "H. Ziyech", "Z. Ibrahimovi\u0107", "A. G\u00f3mez", "G. Higua\u00edn", "B. Matuidi", "G. Bale", "Marcelo", "A. Witsel", "Alex Sandro", "Iago Aspas", "Koke", "J. Rodr\u00edguez", "Allan", "J. Sancho", "K. Havertz", "O. Demb\u00e9l\u00e9", "Kepa", "Jo\u00e3o Cancelo", "D. Alli", "L. Hern\u00e1ndez", "Arthur", "M. Depay", "L. Goretzka", "J. Brandt", "K. Coman", "S. Gnabry", "N. Fekir", "B. Leno", "Luis Alberto", "Alex Telles", "J. Pavlenka", "S. de Vrij", "Felipe Anderson", "Pepe", "Jo\u00e3o Moutinho", "S. Ruffier", "S. Sirigu", "M. Ham\u0161\u00edk", "Sokratis", "Lucas Leiva", "M. \u00d6zil", "Javi Mart\u00ednez", "Y. Sommer", "E. D\u017eeko", "G. Wijnaldum", "I. Peri\u0161i\u0107", "M. Mand\u017euki\u0107", "A. Vidal", "J. Boateng", "Azpilicueta", "Jos\u00e9 Callej\u00f3n", "I. G\u00fcndo\u011fan", "Paulinho", "K. Walker", "Canales", "Douglas Costa", "Pizzi", "D. Tadi\u0107", "J. Ili\u010di\u0107", "R. Mahrez", "E. Vi\u0161\u0107a", "Felipe", "Fabi\u00e1n", "A. Romagnoli", "G. Lo Celso", "T. Alexander-Arnold", "L. Jovi\u0107", "A. Milik", "A. Martial", "Anderson Talisca", "J. Tah", "C. Tolisso", "Pau L\u00f3pez", "Gon\u00e7alo Guedes", "N. P\u00e9p\u00e9", "M. Akanji", "M. Rashford", "J. Stones", "A. Rabiot", "Grimaldo", "T. Werner", "T. Lemar", "D. S\u00e1nchez", "Marco Asensio", "L. Digne", "J. Draxler", "J. Pickford", "Y. Carrasco", "Borja Iglesias", "K. Casteels", "W. Zaha", "Paco Alc\u00e1cer", "Morata", "S. Haller", "William Carvalho", "F. Bernardeschi", "D. Djen\u00e9", "Oscar", "K. Trapp", "Bartra", "Pablo Sarabia", "J. Cillessen", "Lucas Moura", "F. Thauvin", "Jorginho", "G. Buffon", "Casillas", "R. Jarstein", "V. Kompany", "Ra\u00fal Albiol", "F. Quagliarella", "K. Schmeichel", "Falcao", "Miranda", "C. Vela", "E. Garay", "Rui Patr\u00edcio", "R. Nainggolan", "E. Banega", "Diego Costa", "S. Khedira", "David Luiz", "M. Kruse", "J. Henderson", "G. Sigur\u00f0sson", "A. Ramsey", "Illarramendi", "D. Blind", "L. Hr\u00e1deck\u00fd", "N. Otamendi", "J. Cuadrado", "I. Gueye", "K. Kampl", "Rodrigo", "C. Ar\u00e1nguiz", "W. Ben Yedder", "F. Acerbi", "Danilo Pereira", "A. Kramari\u0107", "Louri Beretta", "Josu\u00e9 Chiamulera", "Ronaldo Cabrais", "Oyarzabal", "L. Bailey", "Gabriel Jesus", "M. Kova\u010di\u0107", "A. Belotti", "T. Strakosha", "N. Ke\u00efta", "L. Torreira", "R\u00faben Neves", "P. Kimpembe", "S. Bergwijn", "A. Onana", "N\u00e9lson Semedo", "A. Areola", "M. Perin", "D. Rugani", "A. Correa", "I\u00f1aki Williams", "H. Lozano", "Gelson Martins", "B. Lecomte", "T. Partey", "K. Demirbay", "J. Matip", "Suso", "S. Savi\u0107", "A. R\u00fcdiger", "Pacheco", "Ricardo Pereira", "N. Tagliafico", "David Soria", "Sergio Asenjo", "Muniain", "M. G\u00f6tze", "T. Delaney", "O. Baumann", "Willian Jos\u00e9", "Sergi Roberto", "N. Schulz", "K. Volland", "Nacho Fern\u00e1ndez", "Gabriel Paulista", "J. Roussillon", "H. Maguire", "T. Hazard", "E. Forsberg", "F. Kosti\u0107", "M. Politano", "Rafa", "Pepe Reina", "D. De Rossi", "Aduriz", "Jes\u00fas Navas", "Santi Cazorla", "H. He ...

# %%
set(df_n.player_positions)
# Out:
# {'CAM',
#  'CAM, CDM',
#  'CAM, CDM, CM',
#  'CAM, CF',
#  'CAM, CF, CM',
#  'CAM, CF, RW',
#  'CAM, CF, ST',
#  'CAM, CM',
#  'CAM, CM, CDM',
#  'CAM, CM, CF',
#  'CAM, CM, LM',
#  'CAM, CM, LW',
#  'CAM, CM, RM',
#  'CAM, CM, RW',
#  'CAM, CM, ST',
#  'CAM, LM',
#  'CAM, LM, CF',
#  'CAM, LM, CM',
#  'CAM, LM, LW',
#  'CAM, LM, RM',
#  'CAM, LM, RW',
#  'CAM, LM, ST',
#  'CAM, LW',
#  'CAM, LW, CM',
#  'CAM, LW, RW',
#  'CAM, LW, ST',
#  'CAM, RB',
#  'CAM, RM',
#  'CAM, RM, CF',
#  'CAM, RM, CM',
#  'CAM, RM, LM',
#  'CAM, RM, RB',
#  'CAM, RM, RW',
#  'CAM, RM, ST',
#  'CAM, RW',
#  'CAM, RW, CF',
#  'CAM, RW, CM',
#  'CAM, RW, LW',
#  'CAM, RW, RM',
#  'CAM, ST',
#  'CAM, ST, CDM',
#  'CAM, ST, CF',
#  'CAM, ST, LM',
#  'CAM, ST, LW',
#  'CAM, ST, RM',
#  'CAM, ST, RW',
#  'CB',
#  'CB, CDM',
#  'CB, CDM, CM',
#  'CB, CDM, LB',
#  'CB, CDM, RB',
#  'CB, CM, CDM',
#  'CB, LB',
#  'CB, LB, CDM',
#  'CB, LB, RB',
#  'CB, LWB',
#  'CB, RB',
#  'CB, RB, LB',
#  'CB, RB, RM',
#  'CB, RWB, RB',
#  'CDM',
#  'CDM, CAM, CM',
#  'CDM, CAM, LM',
#  'CDM, CB',
#  'CDM, CB, CM',
#  'CDM, CB, LB',
#  'CDM, CB, RB',
#  'CDM, CM',
#  'CDM, CM, CAM',
#  'CDM, CM, CB',
#  'CDM, CM, LB',
#  'CDM, CM, LM',
#  'CDM, CM, RB',
#  'CDM, CM, RM',
#  'CDM, LB',
#  'CDM, LB, CM',
#  'CDM, RB',
#  'CDM, RB, RM',
#  'CDM, RM',
#  'CDM, RWB',
#  'CF',
#  'CF, CAM',
#  'CF, CAM, CM',
#  'CF, CAM, LM',
#  'CF, CAM, ST',
#  'CF, CM',
#  'CF, CM, LW',
#  'CF, LM',
#  'CF, LM, LW',
#  'CF, LW',
#  'CF, LW, CAM',
#  'CF, LW, RW',
#  'CF, LW, ST',
#  'CF, RM, LM',
#  'CF, RW',
#  'CF, RW, LW',
#  'CF, RW, RM',
#  'CF, RW, ST',
#  'CF, ST',
#  'CF, ST, CAM',
#  'CF, ST, LW',
#  'CF, ST, RM',
#  'CM',
#  'CM, CAM',
#  'CM, CAM, CDM',
#  'CM, CAM, CF',
#  'CM, CAM, LM',
#  'CM, CAM, RM',
#  'CM, CAM, RW',
#  'CM, CAM, ST',
#  'CM, CB',
#  'CM, CB, CAM',
#  'CM, CDM',
#  'CM, CDM, CAM',
#  'CM, CDM, CB',
#  'CM, CDM, CF',
#  'CM, CDM, LB',
#  'CM, CDM, LM',
#  'CM, CDM, LW',
#  'CM, CDM, RB',
#  'CM, CDM, RM',
#  'CM, CDM, RWB',
#  'CM, CF',
#  'CM, CF, CAM',
#  'CM, LB',
#  'CM, LM',
#  'CM, LM, CAM',
#  'CM, LM, CDM',
#  'CM, LM, LB',
#  'CM, LM, RB',
#  'CM, LM, RM',
#  'CM, LW',
#  'CM, LW, RW',
#  'CM, LWB',
#  'CM, LWB, LM',
#  'CM, RB',
#  'CM, RB, RM',
#  'CM, RM',
#  'CM, RM, CAM',
#  'CM, RM, CDM',
#  'CM, RM, RB',
#  'CM, RW',
#  'CM, RW, CAM',
#  'CM, RWB, RM',
#  'CM, ST',
#  'GK',
#  'LB',
#  'LB, CAM, LM',
#  'LB, CB',
#  'LB, CB, CDM',
#  'LB, CB, LM',
#  'LB, CB, LWB',
#  'LB, CDM',
#  'LB, CM',
#  'LB, CM, LM',
#  'LB, LM',
#  'LB, LM, CAM',
#  'LB, LM, LWB',
#  'LB, LM, RM',
#  'LB, LW',
#  'LB, LWB',
#  'LB, LWB, CDM',
#  'LB, LWB, LM',
#  'LB, LWB, RB',
#  'LB, RB',
#  'LB, RB, CB',
#  'LB, RB, RM',
#  'LB, RM',
#  'LB, RM, LM',
#  'LM',
#  'LM, CAM',
#  'LM, CAM, CM',
#  'LM, CAM, LWB',
#  'LM, CAM, RM',
#  'LM, CAM, ST',
#  'LM, CF',
#  'LM, CF, CM',
#  'LM, CF, RM',
#  'LM, CM',
#  'LM, CM, CAM',
#  'LM, CM, LB',
#  'LM, CM, LWB',
#  'LM, LB',
#  'LM, LB, CAM',
#  'LM, LB, CM',
#  'LM, LB, LW',
#  'LM, LB, LWB',
#  'LM, LW',
#  'LM, LW, CAM',
#  'LM, LW, CF',
#  'LM, LW, CM',
#  'LM, LW, LB',
#  'LM, LW, RM',
#  'LM, LW, ST',
#  'LM, LWB',
#  'LM, LWB, LB',
#  'LM, LWB, LW',
#  'LM, RB',
#  'LM, RM',
#  'LM, RM, CAM',
#  'LM, RM, CF',
#  'LM, RM, CM',
#  'LM, RM, LB',
#  'LM, RM, LW',
#  'LM, RM, RB',
#  'LM, RM, ST',
#  'LM, RW',
#  'LM, RW, CAM',
#  'LM, RW, CF',
#  'LM, RW, LW',
#  'LM, RWB',
#  'LM, ST',
#  'LM, ST, CAM',
#  'LM, ST, LW',
#  'LM, ST, RM',
#  'LW',
#  'LW, CAM',
#  'LW, CAM, CM',
#  'LW, CAM, LM',
#  'LW, CAM, RM',
#  'LW, CAM, RW',
#  'LW, CF',
#  'LW, CF, RW',
#  'LW, CF, ST',
#  'LW, CM',
#  'LW, CM, CAM',
#  'LW, LB',
#  'LW, LM',
#  'LW, LM, CF',
#  'LW, LM, LB',
#  'LW, LM, RW',
#  'LW, LM, ST',
#  'LW, RM',
#  'LW, RM, LM',
#  'LW, RW',
#  'LW, RW, CAM',
#  'LW, RW, CM',
#  'LW, RW, LM',
#  'LW, RW, RM',
#  'LW, RW, ST',
#  'LW, ST',
#  'LW, ST, CAM',
#  'LW, ST, LM',
#  'LW, ST, RW',
#  'LWB',
#  'LWB, LB',
#  'LWB, LB, CB',
#  'LWB, LB, LM',
#  'LWB, LB, RB',
#  'LWB, LM',
#  'LWB, LM, LB',
#  'LWB, RM',
#  'LWB, RWB',
#  'RB',
#  'RB, CB',
#  'RB, CB, RM',
#  'RB, CB, RWB',
#  'RB, CB, ST',
#  'RB, CDM',
#  'RB, CDM, CM',
#  'RB, CM',
#  'RB, CM, CB',
#  'RB, CM, CDM',
#  'RB, LB',
#  'RB, LB, CB',
#  'RB, LB, CDM',
#  'RB, LB, RM',
#  'RB, LB, RWB',
#  'RB, LW, LB',
#  'RB, RM',
#  'RB, RM, CB',
#  'RB, RM, CM',
#  'RB, RM, LB',
#  'RB, RM, LM',
#  'RB, RM, RW',
#  'RB, RM, RWB',
#  'RB, RW',
#  'RB, RW, LW',
#  'RB, RWB',
#  'RB, RWB, LB',
#  'RB, RWB, RM',
#  'RM',
#  'RM, CAM',
#  'RM, CAM, CF',
#  'RM, CAM, CM',
#  'RM, CAM, LM',
#  'RM, CAM, RW',
#  'RM, CAM, ST',
#  'RM, CF',
#  'RM, CF, CAM',
#  'RM, CF, LM',
#  'RM, CF, RW',
#  'RM, CM',
#  'RM, CM, LM',
#  'RM, CM, RB',
#  'RM, CM, RW',
#  'RM, LM',
#  'RM, LM, CAM',
#  'RM, LM, CDM',
#  'RM, LM, CF',
#  'RM, LM, CM',
#  'RM, LM, LB',
#  'RM, LM, LW',
#  'RM, LM, RW',
#  'RM, LM, RWB',
#  'RM, LM, ST',
#  'RM, LW',
#  'RM, LW, RW',
#  'RM, RB',
#  'RM, RB, CM',
#  'RM, RB, LB',
#  'RM, RB, RWB',
#  'RM, RW',
#  'RM, RW, CAM',
#  'RM, RW, CM',
#  'RM, RW, LM',
#  'RM, RW, LW',
#  'RM, RW, ST',
#  'RM, RWB',
#  'RM, RWB, CAM',
#  'RM, RWB, LWB',
#  'RM, RWB, RB',
#  'RM, ST',
#  'RM, ST, CAM',
#  'RM, ST, LM',
#  'RM, ST, RW',
#  'RW',
#  'RW, CAM',
#  'RW, CAM, CM',
#  'RW, CAM, LW',
#  'RW, CAM, RM',
#  'RW, CAM, ST',
#  'RW, CF',
#  'RW, CF, LW',
#  'RW, CF, ST',
#  'RW, CM, RM',
#  'RW, LB',
#  'RW, LM, RM',
#  'RW, LW',
#  'RW, LW, CAM',
#  'RW, LW, CM',
#  'RW, LW, LM',
#  'RW, LW, RM',
#  'RW, LW, ST',
#  'RW, RM',
#  'RW, RM, CAM',
#  'RW, RM, CF',
#  'RW, RM, CM',
#  'RW, RM, LM',
#  'RW, RM, LW',
#  'RW, RM, RB',
#  'RW, RM, ST',
#  'RW, RWB',
#  'RW, ST',
#  'RW, ST, CF',
#  'RW, ST, LW',
#  'RW, ST, RM',
#  'RWB',
#  'RWB, RB',
#  'RWB, RB, LB',
#  'RWB, RB, LWB',
#  'RWB, RB, RM',
#  'RWB, RM',
#  'RWB, RM, RB',
#  'ST',
#  'ST, CAM',
#  'ST, CAM, CF',
#  'ST, CAM, CM',
#  'ST, CAM, LM',
#  'ST, CAM, LW',
#  'ST, CAM, RM',
#  'ST, CAM, RW',
#  'ST, CF',
#  'ST, CF, CAM',
#  'ST, CF, LW',
#  'ST, CF, RW',
#  'ST, CM, RB',
#  'ST, LM',
#  'ST, LM, CAM',
#  'ST, LM, LW',
#  'ST, LM, RB',
#  'ST, LM, RM',
#  'ST, LW',
#  'ST, LW, CAM',
#  'ST, LW, LM',
#  'ST, LW, RW',
#  'ST, RM',
#  'ST, RM, CAM',
#  'ST, RM, LM',
#  'ST, RM, LW',
#  'ST, RW',
#  'ST, RW, LM',
#  'ST, RW, LW',
#  'ST, RW, RM',
#  'ST, RWB',
#  nan}

# %% [markdown]
# **Identifiquemos algunos jugadores por nombre**

# %%
print(df_n.loc[0:43,"short_name"])
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             Neymar Jr
# 3              J. Oblak
# 4             E. Hazard
# 5          K. De Bruyne
# 6         M. ter Stegen
# 7           V. van Dijk
# 8             L. Modrić
# 9              M. Salah
# 10            K. Mbappé
# 11         K. Koulibaly
# 12              H. Kane
# 13              Alisson
# 14               De Gea
# 15             N. Kanté
# 16         G. Chiellini
# 17            S. Agüero
# 18         Sergio Ramos
# 19            L. Suárez
# 20       R. Lewandowski
# 21      Sergio Busquets
# 22         A. Griezmann
# 23            P. Dybala
# 24             P. Pogba
# 25              Ederson
# 26          R. Sterling
# 27           C. Eriksen
# 28          T. Courtois
# 29                Piqué
# 30        S. Handanovič
# 31             M. Neuer
# 32            H. Lloris
# 33          David Silva
# 34            E. Cavani
# 35             D. Godín
# 36             T. Kroos
# 37              M. Reus
# 38        P. Aubameyang
# 39              S. Mané
# 40           A. Laporte
# 41       Bernardo Silva
# 42             Casemiro
# 43               H. Son
# Name: short_name, dtype: object
